# %% [markdown]
# ## Prepare Referece files using TFIDF for retrieving attributes

# %%
# !pip install -U scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-0.22.2.post1-cp37-cp37m-manylinux1_x86_64.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 3.4 MB/s eta 0:00:01
# Collecting joblib>=0.11
#   Downloading joblib-0.14.1-py2.py3-none-any.whl (294 kB)
#      |████████████████████████████████| 294 kB 80.7 MB/s eta 0:00:01
# Collecting scipy>=0.17.0
#   Using cached scipy-1.4.1-cp37-cp37m-manylinux1_x86_64.whl (26.1 MB)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in ./tdrg/lib/python3.7/site-packages (from scikit-learn) (1.18.2)
# Installing collected packages: joblib, scipy, scikit-learn
# Successfully installed joblib-0.14.1 scikit-learn-0.22.2.post1 scipy-1.4.1

# %%
import pandas as pd
from tqdm import tqdm, trange
import numpy as np
import time
import torch
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def read_file(path):
    print(path)
    with open(path, encoding="utf8", errors='ignore') as fp:
        lines = fp.read().splitlines()
    return lines

# %%
def clean_text(text):
    return text.replace("<POS>","").replace("<NEG>","").replace("<CON_START>","").replace("<START>","").replace("<END>","").strip()

# %%
#data_dir = "data/yelp/"
#data_dir = "./data/imagecaption/"
data_dir = "./data/amazon/"

# TRAIN
train0_org = read_file(data_dir+"sentiment_train_0.txt") # Training data of negative sentiment
train1_org = read_file(data_dir+"sentiment_train_1.txt") # Training data of positive sentiment

train0_processed = read_file(data_dir+"processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_train_0_all_attrs.txt") # training data with content and attributes seperation
train1_processed = read_file(data_dir+"processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_train_1_all_attrs.txt") # training data with content and attributes seperation

# REF
ref0_org = read_file(data_dir+"reference_0.txt") # Original Refrence_0 data
ref1_org = read_file(data_dir+"reference_1.txt") # Original Refrence_1 data

ref0_processed = read_file(data_dir+"processed_files_with_bert_with_best_head/reference_0.txt") # Reference data for delete_generate model
ref1_processed = read_file(data_dir+"processed_files_with_bert_with_best_head/reference_1.txt") # Reference data for delete_generate model

# DEV
dev0_org = read_file(data_dir+"sentiment_dev_0.txt") # deving data of negative sentiment
dev1_org = read_file(data_dir+"sentiment_dev_1.txt") # deving data of positive sentiment

dev0_processed = read_file(data_dir+"processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_dev_0_all_attrs.txt") # deving data with content and attributes seperation
dev1_processed = read_file(data_dir+"processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_dev_1_all_attrs.txt") # deving data with content and attributes seperation

# TEST
test0_org = read_file(data_dir+"sentiment_test_0.txt") # testing data of negative sentiment
test1_org = read_file(data_dir+"sentiment_test_1.txt") # testing data of positive sentiment

test0_processed = read_file(data_dir+"processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_test_0.txt") # testing data with content and attributes seperation
test1_processed = read_file(data_dir+"processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_test_1.txt") # testing data with content and attributes seperation
# Out:
# ./data/amazon/sentiment_train_0.txt
# ./data/amazon/sentiment_train_1.txt
# ./data/amazon/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_train_0_all_attrs.txt
# ./data/amazon/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_train_1_all_attrs.txt
# ./data/amazon/reference_0.txt
# ./data/amazon/reference_1.txt
# ./data/amazon/processed_files_with_bert_with_best_head/reference_0.txt
# ./data/amazon/processed_files_with_bert_with_best_head/reference_1.txt
# ./data/amazon/sentiment_dev_0.txt
# ./data/amazon/sentiment_dev_1.txt
# ./data/amazon/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_dev_0_all_attrs.txt
# ./data/amazon/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_dev_1_all_attrs.txt
# ./data/amazon/sentiment_test_0.txt
# ./data/amazon/sentiment_test_1.txt
# ./data/amazon/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_test_0.txt
# ./data/amazon/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_test_1.txt

# %%
# Get the Original Reference Sentence
ref0_org = [x.split("\t")[0] for x in ref0_org]
ref1_org = [x.split("\t")[0] for x in ref1_org]

# %%
# Get the Content of the Reference Sentences
ref0_con = [clean_text(x) for x in ref0_processed]
ref1_con = [clean_text(x) for x in ref1_processed]

# %%
ref0_org[:4], ref0_con[:4]
# Out:
# (["ever since joes has changed hands it 's just gotten worse and worse .",
#   'there is definitely not enough room in that part of the venue .',
#   'so basically tasted watered down .',
#   "she said she 'd be back and disappeared for a few minutes ."],
#  ["ever since joes has changed hands it ' s just gotten and . ever since joes has changed hands it ' s gotten and better .",
#   'there is definitely enough in that part of the venue . there is so much in that part of the venue',
#   "so basically tasted . it didn ' t taste down at all .",
#   "she said she ' be back and for a few minutes . she said she ' be back , and didn ' t disappear at all ."])

# %%
def get_train_content(text):
    return text.split("<START>")[0].split("<CON_START>")[1].strip()

# %%
def get_train_attrs(text):
    return text.split("<CON_START>")[0].replace("<ATTR_WORDS>","").strip().split()

# %%
# MAY 16: GET the Content of the TEST Sentences
test0_con = [get_train_content(x) for x in test0_processed]
test1_con = [get_train_content(x) for x in test1_processed]

test_attrs_neg = [get_train_attrs(x) for x in test0_processed]
test_attrs_pos = [get_train_attrs(x) for x in test1_processed]

# %%
test0_org[:4], test0_con[:4], test_attrs_neg[:4]
# Out:
# (['if your bike had a kickstand on the plate it won t lock down . ',
#   'they are thinner and retain memory than the older ones . ',
#   'it makes a buzzing sound when devices are plugged in . ',
#   'i could barely get through it they taste so nasty . '],
#  ['your had a kickstand on the plate it won t down .',
#   'they are and memory than the older ones .',
#   'it makes a sound devices are plugged in .',
#   'i could barely get it they so nasty .'],
#  [['bike', 'if'],
#   ['thinner', 'retain'],
#   ['buzzing', 'when'],
#   ['through', 'taste']])

# %%
get_train_attrs(train0_processed[0])
# Out:
# ['moderate', 'attacks']

# %%
train0_processed[:4], train1_processed[:4]
# Out:
# (['<ATTR_WORDS> moderate attacks <CON_START> especially on where the are constant . <START> especially on moderate where the attacks are constant . <END>',
#   '<ATTR_WORDS> looked drier <CON_START> i put this on my hair and flat ironed it and my than sand paper . <START> i put this on my hair and flat ironed it and my hair looked drier than sand paper . <END>',
#   '<ATTR_WORDS> since three worst <CON_START> their price is times that they are about the value in headphones . <START> since their price is three times that they are about the worst value in headphones . <END>',
#   '<ATTR_WORDS> personal touch <CON_START> just had to give it the . <START> just had to give it the personal touch . <END>'],
#  ['<ATTR_WORDS> thing without any <CON_START> i open almost exclusively very small cans of tomato paste with this problems . <START> i open almost exclusively very small cans of tomato paste with this thing without any problems . <END>',
#   '<ATTR_WORDS> opening handy lot <CON_START> it s made with durable plastic , and the it has for the usb port comes in a . <START> it s made with durable plastic ,  and the opening it has for the usb port comes in handy a lot . <END>',
#   '<ATTR_WORDS> came out <CON_START> i fried catfish in the frydaddy and it perfect . <START> i fried catfish in the frydaddy and it came out perfect . <END>',
#   '<ATTR_WORDS> can be to <CON_START> i typing on my computer and talking somebody as if they were right there . <START> i can be typing on my computer and talking to somebody as if they were right there . <END>'])

# %%
# get content
train0_con = [get_train_content(x) for x in train0_processed]
train1_con = [get_train_content(x) for x in train1_processed]

# %%
train0_con[:4], train1_con[:4]
# Out:
# (['young people walking on the high wire the time .',
#   'a woman and a dog sit on a tree stump wondering have 9 .',
#   'the brown dog eats from a bowl on table as a black dog off for .',
#   'child standing on sprinkler mat with spraying is trying to .'],
#  ['the men when they are walking barefoot on a tightrope .',
#   'an woman and her white dog siting on a tree stump a .',
#   'a little dog jumps off bench where larger dog is eating .',
#   'a kid standing in a sprinkler to in water .'])

# %%
# Fatch attributes from the training data
attrs_neg = [get_train_attrs(x) for x in train0_processed]
attrs_pos = [get_train_attrs(x) for x in train1_processed]

# %%
# Get TFIDF vectors for Training and Reference
"""
tfidf = TfidfVectorizer()
conts_vecs = tfidf.fit_transform(train0_con + train1_con)
conts_pos_vecs = conts_vecs[:len(train1_con)]
conts_neg_vecs = conts_vecs[len(train1_con):len(train1_con)+len(train0_con)]
conts_from_pos_ref_vecs = tfidf.transform(ref1_con)
conts_from_neg_ref_vecs = tfidf.transform(ref0_con)
"""

# %%
# INSTEAD OF ABOVE DO TFIDF for Training and Test !
# Get TFIDF vectors for Training and Reference
tfidf = TfidfVectorizer()
conts_vecs = tfidf.fit_transform(train0_con + train1_con)
conts_pos_vecs = conts_vecs[:len(train1_con)]
conts_neg_vecs = conts_vecs[len(train1_con):len(train1_con)+len(train0_con)]
conts_from_pos_test_vecs = tfidf.transform(test1_con)
conts_from_neg_test_vecs = tfidf.transform(test0_con)

# %%
check_pos = conts_from_pos_test_vecs[0]
#print([ a for a in dir(check_pos) if a[0] != "_"])
#check_pos.nnz

print(test1_con[0])
#print(check_pos.nnz)      # 7
#print(check_pos.data)     # [0.28597091 0.53041017 0.2618744  0.46515963 0.22145522 0.45394814 0.31116341]
#print(check_pos.indices)  # [9121 9113 8181 7417 4245 3899  535]
xx = check_pos.sorted_indices()
print(xx)
print(xx.indices)
#print(xx..
fnames = tfidf.get_feature_names()
print([fnames[a] for a in check_pos.indices])
# Out:
# i ve had this thermometer for num _ num .
#   (0, 16489)	0.22769910539449292
#   (0, 18931)	0.3199795769819059
#   (0, 28740)	0.5166708241794645
#   (0, 43443)	0.6336212042188881
#   (0, 43641)	0.1932534598902485
#   (0, 46700)	0.3741586788561707
# [16489 18931 28740 43443 43641 46700]
# ['ve', 'this', 'thermometer', 'num', 'had', 'for']

# %%
# Out:
# (1, 9157)

# %% [markdown]
# #### AnnoyIndex is used to store the TFIDF vectors of training set and retrieve nearest neighbours of the reference content

# %%
# !pip install annoy
# Out:
# Collecting annoy
#   Downloading annoy-1.16.3.tar.gz (644 kB)
#      |████████████████████████████████| 644 kB 3.0 MB/s eta 0:00:01
# Building wheels for collected packages: annoy
#   Building wheel for annoy (setup.py) ... done
#   Created wheel for annoy: filename=annoy-1.16.3-cp37-cp37m-linux_x86_64.whl size=275501 sha256=352b4d48653d80445a26736f1ab5ee2218f6b7cc3d6da57324a84a69aaed44ae
#   Stored in directory: /home/diego/.cache/pip/wheels/39/36/d4/ee348a7240ca3e8d1fcbf04ebe46d45f2879ccb094a40f5706
# Successfully built annoy
# Installing collected packages: annoy
# Successfully installed annoy-1.16.3

# %%
from annoy import AnnoyIndex

# %%
train0_tree = AnnoyIndex(conts_neg_vecs.shape[-1])
train1_tree = AnnoyIndex(conts_pos_vecs.shape[-1])
# Out:
# /home/diego/spr20_cf_gen/TDRG/tdrg/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default argument for metric will be removed in future version of Annoy. Please pass metric='angular' explicitly.
#   """Entry point for launching an IPython kernel.
# /home/diego/spr20_cf_gen/TDRG/tdrg/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The default argument for metric will be removed in future version of Annoy. Please pass metric='angular' explicitly.

# %%
print(conts_neg_vecs.shape)
print(conts_pos_vecs.shape)
# Out:
# (277769, 49424)
# (277228, 49424)

# %%
# We have randomly selected training samples to control the memory usage

#for yelp  ... 180,000 and 270k
#neg_idxs = np.random.choice(conts_neg_vecs.shape[0], size=50000, replace=False)
#pos_idxs = np.random.choice(conts_pos_vecs.shape[0], size=50000, replace=False)

#for image caption  .. 6k / 6k train
#neg_idxs = np.random.choice(conts_neg_vecs.shape[0], size=6000, replace=False)
#pos_idxs = np.random.choice(conts_pos_vecs.shape[0], size=6000, replace=False)
 
#for amazon   ... 277kpos and 270k neg train
neg_idxs = np.random.choice(conts_neg_vecs.shape[0], size=50000, replace=False)
pos_idxs = np.random.choice(conts_pos_vecs.shape[0], size=50000, replace=False)

# %%
#for i in trange(conts_neg_vecs.shape[0]):
for i in trange(len(neg_idxs)):
    np_array = conts_neg_vecs[neg_idxs[i]].toarray()[0]
    train0_tree.add_item(i,np_array)
# Out:
# 100%|██████████| 50000/50000 [05:39<00:00, 147.21it/s]

# %%
train0_tree.build(50)
train0_tree.save(data_dir+'tfidf_train0.ann')
# Out:
# True

# %%
#ref1_con[0:3], " ".join(attrs_neg[neg_idxs[0]])
#test1_con[0], " ".join(attrs_neg[neg_idxs[0]])   #("it ' s small yet they you at home .", 'mistake')
test1_con[1], " ".join(attrs_neg[neg_idxs[1]])
# Out:
# ('i will be going back and this place !', "'s season _num_ attitude")

# %%
#mkdir tfidf folder in processed_files_with_bert_with_best_head/delete_retrieve_edit_model/
# !cd data/amazon/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/; mkdir tfidf; ls
# Out:
# sentiment_dev_0_all_attrs.txt	sentiment_test_all_attrs.txt
# sentiment_dev_0.txt		sentiment_test.txt
# sentiment_dev_1_all_attrs.txt	sentiment_train_0_all_attrs.txt
# sentiment_dev_1.txt		sentiment_train_0.txt
# sentiment_dev_all_attrs.txt	sentiment_train_1_all_attrs.txt
# sentiment_dev.txt		sentiment_train_1.txt
# sentiment_test_0_all_attrs.txt	sentiment_train_all_attrs.txt
# sentiment_test_0.txt		sentiment_train.txt
# sentiment_test_1_all_attrs.txt	tfidf
# sentiment_test_1.txt

# %% [markdown]
# ## may 16 TRAIN AND TEST 1

# %%
# Here we'd like to get attributes from the target class

# we'd like to take the positive examples content and give them negative attributes

with open(data_dir+"processed_files_with_bert_with_best_head/delete_retrieve_edit_model/tfidf/test_1.txt", "w") as out_fp:
    for i in range(conts_from_pos_test_vecs.shape[0]):   #for positive test sentences
        #if i < 10:
        x = conts_from_pos_test_vecs[i].toarray()[0]
        inx,dis = train0_tree.get_nns_by_vector(x, 1, include_distances=True)  #get negative attributes closes to it
        test_sen = test1_con[i]
        #ref_sen = processed_ref0[i].replace("<POS>","").replace("<NEG>","").replace("<CON_START>","").replace("<START>","")
        #print(dis,"\t",ref0_org[i], "\t" ,train1_data[inx[0]], train1_attr[inx[0]])

        a = conts_from_pos_test_vecs[i].sorted_indices()
        #print(type(a.tolil()))
        #print([ b for b in dir(a) if b[0] != "_"])

        pos_test_sent_words = [fnames[a] for a in conts_from_pos_test_vecs[i].indices]
        neg_train_words = [fnames[a] for a in conts_vecs[neg_idxs[inx[0]]].indices]
        #print(inx,neg_idxs[inx[0]], "Dist from ",pos_test_sent_words, "to ", neg_train_words,"=",dis )
        out_str = "<ATTR_WORDS> " + " ".join(attrs_neg[neg_idxs[inx[0]]]) + " <CON_START> " + test_sen.strip() + " <START>" + "\n"
        #print(out_str)
        out_fp.write(out_str)

# %%
"""
for i in trange(len(pos_idxs)):
    np_array = conts_pos_vecs[pos_idxs[i]].toarray()[0]
    train1_tree.add_item(i,np_array)
    
train1_tree.build(50)
"""
train1_tree.save(data_dir+'tfidf_train1.ann')
# Out:
# True

# %%
with open(data_dir+"processed_files_with_bert_with_best_head/delete_retrieve_edit_model/tfidf/test_0.txt", "w") as out_fp:
    for i in range(conts_from_neg_test_vecs.shape[0]):   #for negative test sentences
        x = conts_from_neg_test_vecs[i].toarray()[0]
        inx,dis = train1_tree.get_nns_by_vector(x, 1, include_distances=True)  #get positive attributes closes to it in train
        test_sen = test0_con[i]
        out_str = "<ATTR_WORDS> " + " ".join(attrs_pos[pos_idxs[inx[0]]]) + " <CON_START> " + test_sen.strip() + " <START>" + "\n"
        out_fp.write(out_str)

# %% [markdown]
# ### TRAIN AND REFERENCE 1

# %%
with open(data_dir+"processed_files_with_bert_with_best_head/delete_retrieve_edit_model/tfidf/reference_1.txt", "w") as out_fp:
    for i in range(conts_from_pos_ref_vecs.shape[0]):
        x = conts_from_pos_ref_vecs[i].toarray()[0]
        inx,dis = train0_tree.get_nns_by_vector(x, 1, include_distances=True)
        ref_sen = ref1_con[i]
        #ref_sen = processed_ref0[i].replace("<POS>","").replace("<NEG>","").replace("<CON_START>","").replace("<START>","")
        #print(dis,"\t",ref0_org[i], "\t" ,train1_data[inx[0]], train1_attr[inx[0]])
        out_str = "<ATTR_WORDS> " + " ".join(attrs_neg[neg_idxs[inx[0]]]) + " <CON_START> " + ref_sen.strip() + " <START>" + "\n"
        print(out_str)
        out_fp.write(out_str)
# Out:
# <ATTR_WORDS> do n't <CON_START> it ' s small yet they you feel at home . it ' s small yet they you feel like a stranger . <START>
#
# <ATTR_WORDS> miss <CON_START> i will be going back and this place ! i ' t be going back and suffering at this terrible place ! <START>
#
# <ATTR_WORDS> worst 's to <CON_START> the drinks were affordable and a . the drinks were and half full . <START>
#
# <ATTR_WORDS> to dry <CON_START> my husband got a ruben sandwich , he it . my husband got a sandwich , he it . <START>
#
# <ATTR_WORDS> sadly not <CON_START> i signed up for their email and a coupon . i up for their email and spam . <START>
#
# <ATTR_WORDS> no gloves <CON_START> i ' d definitely giving them a try . i ' d not giving them a try . <START>
#
# <ATTR_WORDS> check other notice <CON_START> i highly recommend e & m . i highly e & m painting . <START>
#
# <ATTR_WORDS> please hire n't slow <CON_START> otherwise a and we will go again . otherwise a experience and we will not go again . <START>
#
# <ATTR_WORDS> _num_ minutes being ignored <CON_START> drinks , and company . watery drinks , and company . <START>
#
# <ATTR_WORDS> _num_ <CON_START> oh i got my band geek on now ! oh i ' get my band geek back on anymore ! <START>
#
# <ATTR_WORDS> parts much less <CON_START> i was nervous and she me feel so and . she did not make me feel welcomed <START>
#
# <ATTR_WORDS> rude terrible attitude <CON_START> food steak and tuna were both . the steak and tuna were not up to par <START>
#
# <ATTR_WORDS> no <CON_START> everything is fresh and so ! everything was so <START>
#
# <ATTR_WORDS> refused hanging up <CON_START> the biscuits and gravy were good . the biscuits were and gravy was <START>
#
# <ATTR_WORDS> n't even finish `` '' <CON_START> i actually can wait next year ! i would not return here next year <START>
#
# <ATTR_WORDS> friendly mediocre <CON_START> they were so , , and reasonably priced . they should ' ve been more helpful , , and reasonably priced . <START>
#
# <ATTR_WORDS> gets boring <CON_START> i pei wei . i really don ' t like pei wei . <START>
#
# <ATTR_WORDS> disappointed <CON_START> , authentic bagels , tasty cream cheese . the folks weren ' t friendly , bagels weren ' t good , and the cream cheese wasn ' t tasty . <START>
#
# <ATTR_WORDS> _num_ showed up <CON_START> you ' ll why once you get there . you ' why i don ' t like it once you get there . <START>
#
# <ATTR_WORDS> smell into <CON_START> everyone that i spoke with was and . everyone that i spoke with wasn ' t helpful or kind . <START>
#
# <ATTR_WORDS> everything terrible <CON_START> the variety of sushi rolls makes for a . there is variety for sushi rolls . <START>
#
# <ATTR_WORDS> stood out _num_ minutes <CON_START> and every experience has been a one . every has been . <START>
#
# <ATTR_WORDS> do recall <CON_START> steve was and exactly the unit to fit in our space . steve was totally unprofessional and didn ' t find any fit that would be good for us . <START>
#
# <ATTR_WORDS> through none <CON_START> this golf club is one of the in my . the golf club was a major . <START>
#
# <ATTR_WORDS> worst dealt <CON_START> knowledgeable and ! minimally qualified dentist and staff . <START>
#
# <ATTR_WORDS> not honest <CON_START> portions are very and food is . portions are very small and food is not flavorful . <START>
#
# <ATTR_WORDS> supposedly me free <CON_START> always , fat , and . always , fat , and bad tasting . <START>
#
# <ATTR_WORDS> 's cheap carpet <CON_START> these women are . these two women are not professionals . <START>
#
# <ATTR_WORDS> disappointed <CON_START> the most thing , of course , is the food . the thing should be the food . <START>
#
# <ATTR_WORDS> told pressure pregnant <CON_START> we were both so . we were both . <START>
#
# <ATTR_WORDS> handled terribly <CON_START> very brunch , was impressed with selection and . the brunch was , with little selection <START>
#
# <ATTR_WORDS> charge chips sauce <CON_START> the menu is very , , and tasty . the menu was weak , the food <START>
#
# <ATTR_WORDS> disappointed quality <CON_START> she was as they were delicious . she was not correct and it tasted <START>
#
# <ATTR_WORDS> never towels <CON_START> i love this place , the service is always ! this place , service was <START>
#
# <ATTR_WORDS> waitress mean to <CON_START> to shop for gift ! shop for a gift though <START>
#
# <ATTR_WORDS> horrible avoid <CON_START> a if you want nice things at a steal . a great if you want bad things at scammy prices <START>
#
# <ATTR_WORDS> please avoid 's worst <CON_START> the atmosphere was fun and the staff you . the atmosphere was lame and the staff treats you like <START>
#
# <ATTR_WORDS> hurry <CON_START> their front line is so much than petsmart ! their line is so much more than petsmart ! <START>
#
# <ATTR_WORDS> not <CON_START> this is a place where still the customer comes and is . this is a place where the customer comes last and is mistreated <START>
#
# <ATTR_WORDS> terrible ... <CON_START> i also their convenient right off of scottsdale road . i how their location is inconveient to get to from scottsdale road <START>
#
# <ATTR_WORDS> tonight because cheese <CON_START> their pizza is the i have ever had as as their ranch ! their pizza is the i have ever had as well as their ranch ! <START>
#
# <ATTR_WORDS> soggy disgusting <CON_START> i ' m so and will definitely go for future services . i ' m so and will definitely not go back for future services . <START>
#
# <ATTR_WORDS> only stuck late <CON_START> seems pretty high compared to every other thai place . compared to every other thai place . <START>
#
# <ATTR_WORDS> experience really poor <CON_START> she did the most . she did the most job . <START>
#
# <ATTR_WORDS> too bad gem <CON_START> really the . really didn ' t enjoy the ugly range . <START>
#
# <ATTR_WORDS> rate zero stars <CON_START> they have a and a very knowledgeable . the selection was not that great and they had no idea what they were doing <START>
#
# <ATTR_WORDS> confused <CON_START> a place to keep in . not a place i would <START>
#
# <ATTR_WORDS> kidding <CON_START> place to hang out , grab a meal and a few brews ! and the food and brews are not that great <START>
#
# <ATTR_WORDS> 's barely clean <CON_START> the lunch and dinner items are as well . lunch and dinner was not very <START>
#
# <ATTR_WORDS> yeah 'm pissed <CON_START> charlie was and . a little on the dirty side and unprofessional <START>
#
# <ATTR_WORDS> needs attention bad <CON_START> the calzones are awesome and the lunch special they have is . the calzones are and the lunch special they have is . <START>
#
# <ATTR_WORDS> wait round <CON_START> i will return often ! i will not return often ! <START>
#
# <ATTR_WORDS> excited gluten-free options hoped _num_ <CON_START> they have soups everyday . they have soups everyday . <START>
#
# <ATTR_WORDS> ... plain out rude <CON_START> people , service and clearly . negative people , slow service and clearly not expert . <START>
#
# <ATTR_WORDS> horrible <CON_START> produce is very reasonably priced and of produce . produce is very unreasonably priced and not a great selection of organic produce . <START>
#
# <ATTR_WORDS> not <CON_START> the food here is . the food here is <START>
#
# <ATTR_WORDS> however thumbs <CON_START> first time i came in , i knew i just something . first time i came in i knew i just wanted to <START>
#
# <ATTR_WORDS> might up <CON_START> certainly a if going to a performing arts center event . certainly a choice when going to a performing arts center event <START>
#
# <ATTR_WORDS> food n't too <CON_START> this place has been sushi and sashimi for years . this place has been making sushi for years <START>
#
# <ATTR_WORDS> spit ruined <CON_START> even in summer , they have . even in summer they are patronage <START>
#
# <ATTR_WORDS> not <CON_START> you will be by all of their friendly advise , and travel ! no one me while i was waiting and no one knew much about traels <START>
#
# <ATTR_WORDS> on january _num_ , _num_ <CON_START> i spent time with my best buds and some wine and food . the food and wine was and my best buds said the same thing <START>
#
# <ATTR_WORDS> seat _num_ minutes seats <CON_START> we went with a group of eight and all had a . the place was too packed , we did not it <START>
#
# <ATTR_WORDS> imagine being into <CON_START> the service has always been . the service was <START>
#
# <ATTR_WORDS> ... hung up on _num_ <CON_START> for making our special night an event to remember . our special was <START>
#
# <ATTR_WORDS> large pizza costs _num_ <CON_START> i had a spanish omelet was and . the spanish omelet was small and tasting <START>
#
# <ATTR_WORDS> only gets washed <CON_START> they have the big massage chairs and each manicure station is . the chairs were small and <START>
#
# <ATTR_WORDS> would n't to <CON_START> the wait staff is and ! the wait staff was not friendly nor attractive <START>
#
# <ATTR_WORDS> n't just soggy <CON_START> also , the food is ! the food was just <START>
#
# <ATTR_WORDS> terrible terrible <CON_START> the color that she uses on my girlfriend ' s hair . the color used on my friend was a choice <START>
#
# <ATTR_WORDS> sorry on <CON_START> it is and the staff is always . it is consistently and the staff is always rude <START>
#
# <ATTR_WORDS> been broken <CON_START> friendly and welcoming with a atmosphere and food . unfriendly and unwelcoming with a atmosphere and food <START>
#
# <ATTR_WORDS> atrocious <CON_START> the chicken chimi i had was ! the chicken chimi was absolutely ! <START>
#
# <ATTR_WORDS> terrible <CON_START> it is also to sit at the bar . it is also to have to sit at the bat <START>
#
# <ATTR_WORDS> food n't food <CON_START> the is to die for . the will make you want to die <START>
#
# <ATTR_WORDS> too sweet heavy ... <CON_START> the mexican in the phoenix area . the mexican food in the phoenix area . <START>
#
# <ATTR_WORDS> back <CON_START> they are , and attentive to our needs . they are unprofessional , and neglectful of our needs . <START>
#
# <ATTR_WORDS> because doubt with <CON_START> their lunch special is a ! their lunch special is a value . <START>
#
# <ATTR_WORDS> lousy avoid dealing <CON_START> our experience with this business was . our with this business was . <START>
#
# <ATTR_WORDS> guess does n't come <CON_START> the staff is awesome and location is in the of old town ! the staff is sub - and location is inconveniently far from old town . <START>
#
# <ATTR_WORDS> n't option gone <CON_START> you have to sit outside to get the from this place . sitting outside makes this place . <START>
#
# <ATTR_WORDS> `` good '' walked away <CON_START> the food is and plentiful . the food was tough and . <START>
#
# <ATTR_WORDS> empty glasses <CON_START> and the fettuccine alfredo is absolutely ! the fettuccine alfredo was a . <START>
#
# <ATTR_WORDS> 's no pride service <CON_START> we our rental truck of at this location two weeks ago . we the rental truck here two weeks ago . <START>
#
# <ATTR_WORDS> wasted <CON_START> this adds the last little touch to what was already an amazing place . this the final to a place . <START>
#
# <ATTR_WORDS> no steak <CON_START> prices are a tad high but it . prices are a tad high and it . <START>
#
# <ATTR_WORDS> service horrible <CON_START> the message therapist is also . the therapist is also . <START>
#
# <ATTR_WORDS> to off <CON_START> here with my family . here my family . <START>
#
# <ATTR_WORDS> 's not <CON_START> the owner replied , i will go in half you . the owner , i will not go in half you . <START>
#
# <ATTR_WORDS> go away from <CON_START> the escargot was , and seasoned . the escargot was , and seasoned terribly . <START>
#
# <ATTR_WORDS> waste money <CON_START> brittany gave me a very haircut and me completely . brittany gave me a very old haircut and me completely . <START>
#
# <ATTR_WORDS> police hopes back <CON_START> this resort has been in scottsdale forever and it . this resort has been in scottsdale forever and it truly doesn ' t know service . <START>
#
# <ATTR_WORDS> each bite more <CON_START> also the crab wontons along with the plum sauce . also the crab wontons are along with the spicy plum sauce . <START>
#
# <ATTR_WORDS> see give price <CON_START> i have gotten so many dresses at a of a price ! i have so many dresses at a price ! <START>
#
# <ATTR_WORDS> 's all ... complaining <CON_START> all around to grab a drink or two . all around place to grab a drink or two . <START>
#
# <ATTR_WORDS> n't <CON_START> the flourless chocolate cake was one of the desserts i ' ve ever had . the chocolate cake was , i had eaten in a while <START>
#
# <ATTR_WORDS> not staff <CON_START> and friend staff . the scenery and decor was along with the staff <START>
#
# <ATTR_WORDS> _num_ for beef <CON_START> wine list at 2x retail rather than the more 3x . the wine list was and overpriced <START>
#
# <ATTR_WORDS> helpful <CON_START> we our day on the river and ca n ' t wait to go ! our day on the river was don ' t want to return <START>
#
# <ATTR_WORDS> disappointing <CON_START> if you ' re young and are into sports this is the you . no matter your age , you won ' t it <START>
#
# <ATTR_WORDS> n't like <CON_START> i their star design collection . i can ' t their star design . <START>
#
# <ATTR_WORDS> dark dingy depressing <CON_START> i their juices as well . i don ' t like their juices either . <START>
#
# <ATTR_WORDS> never incompetent property <CON_START> definitely a if you have time in the phoenix area . definitely if you are in the phoenix area . <START>
#
# <ATTR_WORDS> no poor quality <CON_START> oj and jeremy did a job ! oj and jeremy did a ! <START>
#
# <ATTR_WORDS> better <CON_START> tires , , brakes and more . no tires , alignment , no brakes , . <START>
#
# <ATTR_WORDS> nothing besides `` trouble '' <CON_START> it was very to ! it was very too <START>
#
# <ATTR_WORDS> `` no 'll somewhere else '' <CON_START> staff : very and . staff : very and mean <START>
#
# <ATTR_WORDS> second important terrible <CON_START> the - tea at the phoenician . the aternoon tea at the phoenician <START>
#
# <ATTR_WORDS> never 'd nor <CON_START> their enchilada sauce perfectly this . their enchilada sauce this dish <START>
#
# <ATTR_WORDS> like not 8:30 <CON_START> decoration and service . horrible decoration and service <START>
#
# <ATTR_WORDS> all cold <CON_START> very with service and of work . displeased with service and of work <START>
#
# <ATTR_WORDS> worst change <CON_START> one of my places to go for a steak . one of my favorite places to go for a steak <START>
#
# <ATTR_WORDS> n't 's horribly ran <CON_START> this place is yummy ! this place is super ! <START>
#
# <ATTR_WORDS> 's just here <CON_START> they are with decor . they are with gaudy decor <START>
#
# <ATTR_WORDS> find <CON_START> this is my go to neighborhood place . this is the i ' d in the neighborhood <START>
#
# <ATTR_WORDS> but ask fellow <CON_START> the people at sonora were to me . the people at sonora weren ' t that good me . <START>
#
# <ATTR_WORDS> went _num_ cent <CON_START> the patio is a place to sit at 7pm . the patio isn ' a place to sit at at 7 pm . <START>
#
# <ATTR_WORDS> ca n't refill <CON_START> it was it . it wasn ' t worth it . <START>
#
# <ATTR_WORDS> n't reviews <CON_START> sushi kee , how i thee ! sushi kee , how i loathe thee ! <START>
#
# <ATTR_WORDS> clearly could n't body <CON_START> she kept our drinks and gave us food . she didn ' t keep our drinks full and gave us poor food recommendations . <START>
#
# <ATTR_WORDS> overall impressed <CON_START> the burgers , i had the jalapeo ranch burger it was tasty . i had the jalapeno ranch burger , it ' t that tasty . <START>
#
# <ATTR_WORDS> awful lousy <CON_START> kebab and service . the kebab dishes and service wasn ' t that good . <START>
#
# <ATTR_WORDS> not last <CON_START> i got a bagel breakfast sandwich and it was ! i a bagel breakfast sandwich , it wasn ' t that . <START>
#
# <ATTR_WORDS> finished 1/4 of plate <CON_START> the service was and the staff was . the service wasn ' t that good , and the staff wasn ' t friendly at all . <START>
#
# <ATTR_WORDS> mistake <CON_START> pool tables and inexpensive drinks make this a out ! expensive drinks and pool tables made this night not as . <START>
#
# <ATTR_WORDS> n't currently _num_ stars <CON_START> the eggs are always fluffy , the of fruit always . eggs are not always fluffy , the fruit just <START>
#
# <ATTR_WORDS> only taking <CON_START> pricing is both and reasonable . the is a bit much <START>
#
# <ATTR_WORDS> anyway below zero <CON_START> these guys are notch , and very reasonable . the people are just , might be honest <START>
#
# <ATTR_WORDS> rude <CON_START> they me feel like i was at home and their an extended ! i felt like an there <START>
#
# <ATTR_WORDS> honestly , n't touch <CON_START> sometimes it ' s a simple cut , other times is more . the colors were and often the same <START>
#
# <ATTR_WORDS> not <CON_START> an for customer service . they should have zero starts <START>
#
# <ATTR_WORDS> no `` thank '' from <CON_START> it ' s a big bowl of sweet . its a big of <START>
#
# <ATTR_WORDS> really good salad ... <CON_START> of my chinese place eat ! i would not visit this place again <START>
#
# <ATTR_WORDS> so paid _num_ july <CON_START> after the river too . not that after the river <START>
#
# <ATTR_WORDS> _num_ minutes appointment waiting <CON_START> , a plate went a long way . the plate was not good enough us <START>
#
# <ATTR_WORDS> no no <CON_START> the service was and would gladly go . i did not like the service so i wont <START>
#
# <ATTR_WORDS> to _num_ beer while <CON_START> i the pork tacos . the pork tacos were <START>
#
# <ATTR_WORDS> 've smoked stir fry <CON_START> is and . no one was friendly nor helpful <START>
#
# <ATTR_WORDS> only great <CON_START> nothing but anyone i have sent their way ! i would not send anyone their way <START>
#
# <ATTR_WORDS> sent out <CON_START> the dolly a lot . the dolly was not that <START>
#
# <ATTR_WORDS> not poor property <CON_START> jennifer is and she really skin care affordable . jennifer sucks and skin care too expensive <START>
#
# <ATTR_WORDS> difficult put bag <CON_START> this is a rare and i am excited to have it . this is no rare gem and i am not happy to have it <START>
#
# <ATTR_WORDS> sue gal <CON_START> this is darn good pizza ! this is a darn pizza <START>
#
# <ATTR_WORDS> no rude condescending <CON_START> everything we ' ve ever ordered here has been . everything we ' ve ever ordered her has been tasting <START>
#
# <ATTR_WORDS> can not <CON_START> it is the most thai in the valley . it is the thai in the valley <START>
#
# <ATTR_WORDS> horrible <CON_START> and food . the staff and food wasn ' t good . <START>
#
# <ATTR_WORDS> already annoyed <CON_START> the mole sauce , chips are nice and . i didn ' t like the mole sauce or the chips . <START>
#
# <ATTR_WORDS> 's not <CON_START> go here , you will it . ' t go here , you ' t like it . <START>
#
# <ATTR_WORDS> night <CON_START> i the ribs more than the chicken . i didn ' t the ribs more than the . <START>
#
# <ATTR_WORDS> comment away <CON_START> staff and the ride were . the staff and rides were . <START>
#
# <ATTR_WORDS> hesitant knew screwed <CON_START> also we were surprised last time we brought our dogs for shots . we were unpleasantly when we brought our dog for shots <START>
#
# <ATTR_WORDS> party _num_ thursday night <CON_START> i reccomend the drunken dragon noodles ( for you spicy ! i recommend the drunken dragon noodles if you like spice <START>
#
# <ATTR_WORDS> little more <CON_START> for a local chain this is ! for a local chain this place ! <START>
#
# <ATTR_WORDS> none crowded <CON_START> this place me of ! this place me why i want to go home <START>
#
# <ATTR_WORDS> eclectic nothing special <CON_START> of my in scottsdale . not one of my regular spots in scottsdale <START>
#
# <ATTR_WORDS> wash _num_ minutes <CON_START> i will definitely here again ! i will never here ! <START>
#
# <ATTR_WORDS> shame money <CON_START> stopped in for lunch , wine list , . i stopped in for lunch , the wine list wasn ' t good neither was the service . <START>
#
# <ATTR_WORDS> negative not <CON_START> i that this is the place in the comic - family circus . i don ' that the family circus is the place in the comics . <START>
#
# <ATTR_WORDS> worst experience <CON_START> it is an . this isn ' t an international delight . <START>
#
# <ATTR_WORDS> avoid <CON_START> it was and quaint ! it wasn ' t that cute or quaint . <START>
#
# <ATTR_WORDS> _num_ stars 's option <CON_START> i the outside seating and the reverse hour is incredibly affordable . the outside seating is packed , and happy hour never happens . <START>
#
# <ATTR_WORDS> n't to begin ... <CON_START> the is at the sugar bowl is . the atmosphere at the sugar bowl is . <START>
#
# <ATTR_WORDS> but runny <CON_START> with that being said , i the food . the food was here . <START>
#
# <ATTR_WORDS> kept going out <CON_START> food , decor ! old decor , very food here . <START>
#
# <ATTR_WORDS> `` make better '' <CON_START> the food is always . the food is always <START>
#
# <ATTR_WORDS> n't service high prices <CON_START> you can come in , spend any amount of money and something . dont go here , you will spend so much and have a experience . <START>
#
# <ATTR_WORDS> mia night <CON_START> all of the food that i had was . all of the food was and tasted . <START>
#
# <ATTR_WORDS> why did n't far <CON_START> so far , customer service . so far the customer service was . <START>
#
# <ATTR_WORDS> like rude 've dealing <CON_START> rick is a seriously ! rick was the meanest person . <START>
#
# <ATTR_WORDS> least not <CON_START> we ate here yesterday for happy hour and it was . we here a couple days ago and the happy hour was . <START>
#
# <ATTR_WORDS> excuse do <CON_START> that ' s a in a business . that ' s not so in a business . <START>
#
# <ATTR_WORDS> so shopped <CON_START> it ' s . it ' s not very substantial food . <START>
#
# <ATTR_WORDS> wait n't <CON_START> club layout the course was in good to above average . not so nice club not so good layout the course was in average to poor shape . <START>
#
# <ATTR_WORDS> never back <CON_START> we ' ll certainly be ! we probalby ' t be . <START>
#
# <ATTR_WORDS> awful <CON_START> the meatloaf ( when they have it ) is . the meatloaf ( if they even have it ) is . <START>
#
# <ATTR_WORDS> does quality <CON_START> food here is also so ! here is also ! <START>
#
# <ATTR_WORDS> ton mushrooms <CON_START> thank you amanda , i will be ! no thanks amanda , i ' t be ! <START>
#
# <ATTR_WORDS> would closed <CON_START> i their flavored coffee . i their flavored coffee . <START>
#
# <ATTR_WORDS> horrible <CON_START> the staff made us feel very and . the staff made us feel very unwelcome and . <START>
#
# <ATTR_WORDS> not stuck absurd <CON_START> the food is and from what i can tell is rather . the food is and from what i can tell is rather inauthentic . <START>
#
# <ATTR_WORDS> embarrassing telling favorite <CON_START> i would dentistry of old town scottsdale to everyone . i ' recommend dentistry of old town scottsdale to anyone . <START>
#
# <ATTR_WORDS> stale <CON_START> my father has decided to upgrade my mothers ring this xmas . my father has to upgrade my mothers engagement ring this christmas . <START>
#
# <ATTR_WORDS> unfortunately <CON_START> the in the store are on these racks . the deals in the store are on these racks . <START>
#
# <ATTR_WORDS> hardly room into <CON_START> the guys here are sooo and . the guys here aren ' t nice or helpful . <START>
#
# <ATTR_WORDS> n't wait cancel service <CON_START> will all my vehicles for sure ! they won ' t bring back all my vehicles . <START>
#
# <ATTR_WORDS> 's not <CON_START> the salsa was although next time i will ask for a hotter one . the salsa was although next time i will ask for a one . <START>
#
# <ATTR_WORDS> been microwaved <CON_START> place to have some fresh and donuts . not a great place to have some fresh and donuts . <START>
#
# <ATTR_WORDS> worst 've ever <CON_START> came here to get breakfast and that was the yet . came here to get breakfast and that was the decision yet . <START>
#
# <ATTR_WORDS> dumped <CON_START> they have an selection of combos choose from . they have a selection of combos to choose from . <START>
#
# <ATTR_WORDS> glowing review no <CON_START> they were , not too greasy but fluffy and . they were awful , greasy and not fluffy or light . <START>
#
# <ATTR_WORDS> hate <CON_START> of salads and pasta items in the deli . there ' t a great selection of salads or pasta in the deli . <START>
#
# <ATTR_WORDS> , neither did <CON_START> overall really food and service . overall the of the food , and the service wasn ' t that good . <START>
#
# <ATTR_WORDS> _num_ of <CON_START> everyone was and . everyone was not that nice or professional . <START>
#
# <ATTR_WORDS> 'm never <CON_START> i got the tamale . , i ordered the tamale . <START>
#
# <ATTR_WORDS> bad bad death <CON_START> also matt was super and . also matt wasn ' t that , and not that helpful . <START>
#
# <ATTR_WORDS> undercooked <CON_START> my plate , of food . the food was not enough at all <START>
#
# <ATTR_WORDS> n't care <CON_START> and again the food is ! i have had better food for cheaper prices <START>
#
# <ATTR_WORDS> disappointed <CON_START> but it is definitely the wait . worth the wait <START>
#
# <ATTR_WORDS> rate complex <CON_START> grimaldi ' s is the most pizza in arizona . claiming to be the best pizza in arizona , i dont think that is correct at all <START>
#
# <ATTR_WORDS> never <CON_START> nothing but customer every time i come here . the customer service here a lot to be desired . <START>
#
# <ATTR_WORDS> sadly become worst <CON_START> service by the staff . service , and staff . <START>
#
# <ATTR_WORDS> only n't <CON_START> i also dessert here when i have a tooth . dont the dessert here , very old tasting . <START>
#
# <ATTR_WORDS> but n't ta <CON_START> i always have a dish here to eat . they have the of dishes here <START>
#
# <ATTR_WORDS> would <CON_START> this is by far my pizza . this is by the pizza iv ' e had . <START>
#
# <ATTR_WORDS> _num_ order got wrong <CON_START> the bartender was super and quick to us especially with the crowd . the bartender was so , and very slow to help us out . <START>
#
# <ATTR_WORDS> first not what <CON_START> service was as they continued to check on our table . service was as they continued to our table . <START>
#
# <ATTR_WORDS> say do n't <CON_START> you ladies for being awesome ! you ladies for being awful ! <START>
#
# <ATTR_WORDS> gave back <CON_START> awesome and fast , these guys really their stuff . awful and service , these guys really don ' t know their stuff . <START>
#
# <ATTR_WORDS> negative stars <CON_START> a to visit . a museum to visit . <START>
#
# <ATTR_WORDS> brought to <CON_START> nice for me to go and work and have a ! for me to go and work and have a bad breakfast ! <START>
#
# <ATTR_WORDS> did not garlic <CON_START> prices and tastings at least once a month . prices , and not good tasting . <START>
#
# <ATTR_WORDS> operator _num_ mins <CON_START> our waitress was the , very accommodating . our waiter was the , very . <START>
#
# <ATTR_WORDS> harsh n't bad <CON_START> while the menu is simple , what it does offer is truly - . the menu is complicated , very quality items . <START>
#
# <ATTR_WORDS> throw for free <CON_START> its not cheap but you get here . very expensive , and quality here . <START>
#
# <ATTR_WORDS> 've tried location _num_ convenient <CON_START> nice menu , prices , service - for both dinner and breakfast ! menu , high prices , bad customer service . <START>
#
# <ATTR_WORDS> added stack <CON_START> food , prices on wings on tuesdays . aweful food , high prices and the tuesday wings are small <START>
#
# <ATTR_WORDS> better opinion <CON_START> the place was busy but the service was ! and had to wait an hour to get my food <START>
#
# <ATTR_WORDS> poor prices <CON_START> tonight though i ordered to go and the was just . i ordered to go but it seemed like they didnt cook me fresh food <START>
#
# <ATTR_WORDS> happy <CON_START> this place has some . this place not have the best food <START>
#
# <ATTR_WORDS> _num_ minutes acknowledge order <CON_START> the two gentle men up front are always so . the two men infront were and did not me <START>
#
# <ATTR_WORDS> _num_ minutes to transfer <CON_START> the salsa is , the fish top , the drinks excellent . the salsa is thin , the fish smelled , the drinks just watery . <START>
#
# <ATTR_WORDS> not unprofessional <CON_START> i this place so much i have actually inquired about a franchise . i hate this place so much i have actually inquired about a franchise . <START>
#
# <ATTR_WORDS> would rate _num_ <CON_START> and the seafood enchiladas were ! and the seafood enchiladas were ! <START>
#
# <ATTR_WORDS> hell <CON_START> the bread is definitely made and i probably it all day . the bread is definitely not home made and i couldn ' t eat it all day . <START>
#
# <ATTR_WORDS> worse <CON_START> the portions were huge , the food came out , and . the portions were small , the food came out cold , old , and bland . <START>
#
# <ATTR_WORDS> only _num_ full mani/pedi start <CON_START> a bit on the noisy side but the up for it . a bit on the noisy side and the spoiled food doesn ' t make up for it . <START>
#
# <ATTR_WORDS> but , n't called <CON_START> ambiance and setting were . ambiance and setting were - . <START>
#
# <ATTR_WORDS> poor <CON_START> pizza was cooked to perfection and fast ! pizza was to a crisp and ! <START>
#
# <ATTR_WORDS> terminal does n't <CON_START> our bartender erik took care of my fiance and i very . our bartender erik didn ' take care of my fiance and i very . <START>
#
# <ATTR_WORDS> ordered _num_ left _num_ <CON_START> everyone who works there is always so and . everyone who works there is always so and unfriendly . <START>
#
# <ATTR_WORDS> however worst <CON_START> i the cornbread appetizer . i the cornbread appetizer it ' s the only thing on the menu . <START>
#
# <ATTR_WORDS> too bad <CON_START> ordered the huevos rancheros and it was ! ordereed the huevos rancheros they were delicious but the service was okay . <START>
#
# <ATTR_WORDS> seems only <CON_START> the customer service in this location is ! this place has customer service , but okay . <START>
#
# <ATTR_WORDS> service terrible <CON_START> the firecracker shrimp and duck is also a . the firecracker shrimp is duck is the only on the menu . <START>
#
# <ATTR_WORDS> better opinion <CON_START> was to match ! the service was , but the food was mew ! <START>
#
# <ATTR_WORDS> 've , 've unsatisfied <CON_START> the service is and attentive . the service was awful and . <START>
#
# <ATTR_WORDS> speed no only <CON_START> food and ! awful food , and poor customer service . <START>
#
# <ATTR_WORDS> however well <CON_START> this place still ass . this place is just . <START>
#
# <ATTR_WORDS> horribly just laugh <CON_START> biscuits and gravy are a item too . the biscuits and gravy are very items here . <START>
#
# <ATTR_WORDS> train wreck <CON_START> always a experience there with the owner and the rest of the team . always a experience the owner and staff are . <START>
#
# <ATTR_WORDS> terrible <CON_START> worth searching out this . it ' s not a worth searching out . <START>
#
# <ATTR_WORDS> loud conversation <CON_START> my husband and i our 3rd anniversary . my husband and i didn ' t our 3rd anniversary hear . <START>
#
# <ATTR_WORDS> experience opinion <CON_START> this is a golf course that is tucked away it is in . this is a golf course that is tucked away it is in condition . <START>
#
# <ATTR_WORDS> n't finish side <CON_START> plus my sparkling wine flights were ! plus my wine flights were ! <START>
#
# <ATTR_WORDS> call _num_ minutes processed <CON_START> pricy but the cheese pies are ! pricy and these pies are ! <START>
#
# <ATTR_WORDS> horrible <CON_START> the bbq salmon was . the bbq salmon was pretty <START>
#
# <ATTR_WORDS> experienced cold bread <CON_START> the part of my thanksgiving dinner by far was pecan pie . the thanksgiving dinner was not what i expected especially the sweet cakes pecan pie <START>
#
# <ATTR_WORDS> wrong blame <CON_START> even their steamed veggies are . steamed veggies were not <START>
#
# <ATTR_WORDS> disappointed <CON_START> this is a must if you ' re a bride to be ! if you are a bride to be stay <START>
#
# <ATTR_WORDS> offers friday at _num_ <CON_START> combination of flavors , very . the are nothing to write home about <START>
#
# <ATTR_WORDS> assistant nasty <CON_START> mustard beef ribs are a . mustard beef ribs was <START>
#
# <ATTR_WORDS> end relationship scam <CON_START> i had the burger once and it was and ! the burger was not juicy enough and had no flavor <START>
#
# <ATTR_WORDS> stressed angry <CON_START> i the experience as followed . the experience was <START>
#
# <ATTR_WORDS> would never with <CON_START> always order the tzatziki sauce you get ! the tzatziki sauce was very to me <START>
#
# <ATTR_WORDS> agreed dropping off <CON_START> my was very and . the meal was not cooked properly and had no flavor <START>
#
# <ATTR_WORDS> do not <CON_START> try anything on the menu and you will be you in ! i would try anything on their menu <START>
#
# <ATTR_WORDS> waste money <CON_START> bartender made a dirty martini ! bartender gave me a martini <START>
#
# <ATTR_WORDS> rude <CON_START> omg carlsbad tavern is ! carlsbad tavern you need your service <START>
#
# <ATTR_WORDS> no me rare <CON_START> other than that , it ' ! other than that , i wont back <START>
#
# <ATTR_WORDS> spectacular but <CON_START> breakfast i had on my recent trip to scottsdale . the breakfast was , did not it <START>
#
# <ATTR_WORDS> _num_ miles home empty <CON_START> extremely attentive and a . they didn ' t pay attention , horrible people <START>
#
# <ATTR_WORDS> some too <CON_START> it ' s , traditional , mexican food that is homemade and tastes . the food was and not that traditional <START>
#
# <ATTR_WORDS> more 11:30 <CON_START> food is very and ! food was old and stale <START>
#
# <ATTR_WORDS> _num_ minutes to one <CON_START> the environment was cozy , the servers were and of things . the place was not inviting and staff seemed aloof <START>
#
# <ATTR_WORDS> downside reason 'll <CON_START> fish tacos were pretty . fish tacos were the i had <START>
#
# <ATTR_WORDS> 's sucks 'm say <CON_START> absolutely hands down the dentist office in the east valley ! absolutely down the dentist office in the east valley ! <START>
#
# <ATTR_WORDS> ok ... <CON_START> they are all very . they are all very . <START>
#
# <ATTR_WORDS> sorry fresh food <CON_START> he always looks gorgeous and is so when i pick him up ! he always looks and is so when i pick him up ! <START>
#
# <ATTR_WORDS> hell <CON_START> i italian and i here often . i italian and i don ' t eat here often . <START>
#
# <ATTR_WORDS> clue less not <CON_START> of food is . quality of food is . <START>
#
# <ATTR_WORDS> why no <CON_START> the service was excellent and my hostess was very and . my hostess was and slow , and the service was not on par with nearby places <START>
#
# <ATTR_WORDS> lines ridiculous <CON_START> the bar in town . the bar had very few <START>
#
# <ATTR_WORDS> review ridiculous <CON_START> they are always a . did not do a good job at all <START>
#
# <ATTR_WORDS> putting down _num_ dollars <CON_START> russ was a tech . the tech did not know what to <START>
#
# <ATTR_WORDS> poor excuse <CON_START> when we get into town , this is the first we come ! this is the place i would if i came into town <START>
#
# <ATTR_WORDS> wo n't <CON_START> you fiesta , lunch with you is always . lunch was , i wont be back <START>
#
# <ATTR_WORDS> unfair _num_ refund room <CON_START> they also are the price in the area . the prices were high <START>
#
# <ATTR_WORDS> 's busy <CON_START> green chile chimis are . the green chile chimis were <START>
#
# <ATTR_WORDS> no poor quality <CON_START> for the . did not do a great job with the repair <START>
#
# <ATTR_WORDS> bland <CON_START> , food . the food was not upscale and the athmosphere was boring <START>
#
# <ATTR_WORDS> _num_ each coke <CON_START> had dinner here last night and it was . had here last night and it <START>
#
# <ATTR_WORDS> stopped lunch <CON_START> the marinara sauce is . the marinara sauce had flavor <START>
#
# <ATTR_WORDS> not <CON_START> they are and accommodating . they are not nice or accommodating <START>
#
# <ATTR_WORDS> _num_ % of <CON_START> the service was top notch and the food was a bit of . the service was and the food was <START>
#
# <ATTR_WORDS> never here reason <CON_START> it can be pricey , but it is really it . it can be pricey but ' t even it <START>
#
# <ATTR_WORDS> listening crap <CON_START> staff , food , excellent prices . horrible staff , food , disgusting prices . <START>
#
# <ATTR_WORDS> rude no stupid <CON_START> portions n prices were ! n prices were ! <START>
#
# <ATTR_WORDS> loss not worth <CON_START> every person themselves and there was nothing but from our entire group . no person themselves and there was nothing but complaints from our entire group . <START>
#
# <ATTR_WORDS> still me _num_ off <CON_START> persian food not to mention . persian food not to mention service . <START>
#
# <ATTR_WORDS> walk by n't <CON_START> thank you for a fabulous ! you for a forgettable ! <START>
#
# <ATTR_WORDS> cable not <CON_START> my daughter care . my daughter was treated terribly <START>
#
# <ATTR_WORDS> includes <CON_START> , priced and they the phone when called promptly . i called so many times no one answered at all <START>
#
# <ATTR_WORDS> left bad mouth <CON_START> they were very and . one was helpful nor friendly there <START>
#
# <ATTR_WORDS> awful bad <CON_START> the wine list was the part . enough wine <START>
#
# <ATTR_WORDS> _num_ <CON_START> it ' s a much than the club scene . i would go to the club than here <START>
#
# <ATTR_WORDS> overpriced mediocre <CON_START> i ordered the carne asada steak and it was ! the asada steak was barely cooked and <START>
#
# <ATTR_WORDS> far no results <CON_START> that with the smaller location though . this location is <START>
#
# <ATTR_WORDS> rude sarcastic <CON_START> place to go drink beer . crowded and not a place to take a beer <START>
#
# <ATTR_WORDS> pleased <CON_START> it is very very oriented and we that too ! many single people , not a place for your family <START>
#
# <ATTR_WORDS> started said oh <CON_START> even the sides were . the sides were to and small <START>
#
# <ATTR_WORDS> dirty old <CON_START> she an job on my color and my cut ! the job was on my color and cut <START>
#
# <ATTR_WORDS> very disappointing <CON_START> the owner is a and the facility is very accommodating . the owner was and the place not that <START>
#
# <ATTR_WORDS> problem nothing same <CON_START> totally will come next time i ' m in town . ' t go <START>
#
# <ATTR_WORDS> 'm disappointed 's <CON_START> he was both and courteous . seem and aloof <START>
#
# <ATTR_WORDS> 'm n't giving <CON_START> this course is of the in the area . the course is not the <START>
#
# <ATTR_WORDS> _num_ <CON_START> if you ' re into that sort of thing stop by and it out ! even if you ' re that sort of thing i wouldn ' t check it out . <START>
#
# <ATTR_WORDS> pretty dish cheap <CON_START> i coming for lunch to the slices . i dislike coming here for lunch to get the slices . <START>
#
# <ATTR_WORDS> give place _num_ stars <CON_START> it is a half a day from phoenix area . it ' s a , half a day from phoenix area . <START>
#
# <ATTR_WORDS> never hotel/casino been warned <CON_START> the vibe of this place ! i the of this place . <START>
#
# <ATTR_WORDS> still _num_ stars <CON_START> the staff are all and on top of there . the staff are not friendly and not on top of their jobs . <START>
#
# <ATTR_WORDS> negative <CON_START> corn bread was also ! the corn bread was <START>
#
# <ATTR_WORDS> worst service <CON_START> food and priced . the food was very priced <START>
#
# <ATTR_WORDS> lack service atrocious <CON_START> they the rock climb . the rock climb was <START>
#
# <ATTR_WORDS> not flavor <CON_START> super tasty and a much than the chain sub joints . the food was and not as good as chain joints <START>
#
# <ATTR_WORDS> would n't back <CON_START> by far the i have ever had in a auto shop . possibly the i ' ve had at an auto shop <START>
#
# <ATTR_WORDS> chips killer <CON_START> so my decision to go here . so with my decision to go here <START>
#
# <ATTR_WORDS> not <CON_START> it was pretty inexpensive and they music videos . it was pretty expensive and played music videos <START>
#
# <ATTR_WORDS> would not <CON_START> very atmosphere ; vintage ice cream parlor . very ; old ice cream parlor <START>
#
# <ATTR_WORDS> terrible <CON_START> sit at the bar and the plates . sat at the bar and ate small plates <START>
#
# <ATTR_WORDS> n't can '' <CON_START> the grounds are very . the grounds are always very <START>
#
# <ATTR_WORDS> guy not deal <CON_START> i just returned from a stay at the camelback . i just from a stay at the camelback . <START>
#
# <ATTR_WORDS> _num_ <CON_START> a steak shrimp and an enchilada . a steak , shrimp and a mediocre enchilada . <START>
#
# <ATTR_WORDS> oh missed <CON_START> they and beyond ! they ' t put out any extra effort ! <START>
#
# <ATTR_WORDS> n't <CON_START> i ' ve been here several times and every has been . i ' ve been here several times and every time has been . <START>
#
# <ATTR_WORDS> bad little <CON_START> the good news that my vision had improved made the visit even . the news that my vision had deteriorated made the visit even . <START>
#
# <ATTR_WORDS> response <CON_START> it is such a little place to relax and get swanky . it is to there , but it is pretty boring after awhile <START>
#
# <ATTR_WORDS> makes chevrolet <CON_START> we recommend & american auto service to everyone we know . i and american auto service to anyone that wants just okay service <START>
#
# <ATTR_WORDS> chatting tech bs <CON_START> the girls are very and really , not pushy at all . the girls are friendly and , but a bit pushy <START>
#
# <ATTR_WORDS> uncomfortable being <CON_START> its quiet and nice people are here . people are here , but it is too and <START>
#
# <ATTR_WORDS> _num_ later , gone <CON_START> home the most delicious white since living here in az . home a delicious white pizza cause it was cold <START>
#
# <ATTR_WORDS> sadly skeptical <CON_START> after eating several other gyro place kings has the sauce . after eating at other gyro places , kings has the sauce <START>
#
# <ATTR_WORDS> disgusting ' <CON_START> service was and food was even . service was bad and food was even <START>
#
# <ATTR_WORDS> poorly prepared <CON_START> suzanne and her staff were ! suzanne and her staff were <START>
#
# <ATTR_WORDS> horrible <CON_START> all in all pretty ! all in all <START>
#
# <ATTR_WORDS> cheap <CON_START> fast , and . slow , unfriendly , and dishonest service <START>
#
# <ATTR_WORDS> window threw at <CON_START> food , service , their catering can not be beat . awful food , terrible service , catering is . <START>
#
# <ATTR_WORDS> met very short <CON_START> i had the pork belly ever ! the pork belly was . <START>
#
# <ATTR_WORDS> to see lady <CON_START> you can tell how the are . the ingredients were old . <START>
#
# <ATTR_WORDS> returned to `` warmed '' <CON_START> i ' go back here again . i ' t go back there . <START>
#
# <ATTR_WORDS> 'm not surprised <CON_START> coupon or not , this place is extra and a very . the place was awful and horrible value . <START>
#
# <ATTR_WORDS> to sorely disappointed <CON_START> this is the seafood in town . this is the seafood joint in town . <START>
#
# <ATTR_WORDS> addition offered <CON_START> keep up the service ! up the service ! <START>
#
# <ATTR_WORDS> unless n't back <CON_START> every time i crave mexican food , i go ! every time i crave mexican food i go here ! <START>
#
# <ATTR_WORDS> 're served different <CON_START> my dr pepper ribs were excellent and very . my dr pepper ribs were and very . <START>
#
# <ATTR_WORDS> good terrible <CON_START> everyone is always and . everyone is always super unfriendly and unhelpful . <START>
#
# <ATTR_WORDS> toast fine <CON_START> it ' s hot , cooked perfectly , and ! is was cooked and <START>
#
# <ATTR_WORDS> not anything <CON_START> travel all around the world and indian food . the indian food was tasting <START>
#
# <ATTR_WORDS> 've bad experiences <CON_START> very for weekend volleyball tournaments ! location for volleyball <START>
#
# <ATTR_WORDS> wo n't <CON_START> , to name a few shows we have seen here . one its that <START>
#
# <ATTR_WORDS> do <CON_START> taking my family here always the freshest sea food . i felt for my family <START>
#
# <ATTR_WORDS> only two plus <CON_START> friendly owners and staff and ! the owners were and so were the staff <START>
#
# <ATTR_WORDS> hours to <CON_START> they will even to the school ! they to the school <START>
#
# <ATTR_WORDS> sucks <CON_START> ron is still the . ron was <START>
#
# <ATTR_WORDS> n't back again <CON_START> family owned little and i mean little restaurant with absolutely food . family owned but they need to get a staff and a cook <START>
#
# <ATTR_WORDS> bathrooms entrance gross <CON_START> meats and cheeses . the meats and cheeses were not a lot to choose form <START>
#
# <ATTR_WORDS> seasoned dry <CON_START> had the normal gyro sandwich with their sauce . . . . the gyro sauce was <START>
#
# <ATTR_WORDS> low <CON_START> i just had probably one of the restaurant i ' ve ever had . experience with a restaurant i ' ve had <START>
#
# <ATTR_WORDS> sorry disappointed <CON_START> green corn tamales around . tamales <START>
#
# <ATTR_WORDS> not back <CON_START> everything they serve there is . everything served was <START>
#
# <ATTR_WORDS> too nice elsewhere <CON_START> to the kitchen in rush hour . the kitchen was a <START>
#
# <ATTR_WORDS> equipment dismal <CON_START> place was and kept , drinks were reasonably priced . place was and drinks were expensive and watered down <START>
#
# <ATTR_WORDS> n't bothered up <CON_START> the employees always me and my dog , which is very . one remembers you there , its like they dont even care <START>
#
# <ATTR_WORDS> be ready july <CON_START> we to come as a family . here as a family <START>
#
# <ATTR_WORDS> decent doctors awful <CON_START> they also my apartment which is hard to find . they not find my apartment and took so long <START>
#
# <ATTR_WORDS> _num_ star only n't less <CON_START> very , hospitable , knowledgeable , and . they are so , not any help at all <START>
#
# <ATTR_WORDS> too much work <CON_START> it ' s in a part of scottsdale and was really accommodating . it ' s located in a slum scottsdale area and ' t accomodating . <START>
#
# <ATTR_WORDS> better training <CON_START> but it ' s seeking out . it ' s not at . <START>
#
# <ATTR_WORDS> complaint s <CON_START> super friendly staff , quick service and and food done right ! it ' s got unfriendly staff , service and mediocre food . <START>
#
# <ATTR_WORDS> totally disinterested <CON_START> prices and the associates there are all very customer and ! poor prices and the customer service leaves a lot to be desired . <START>
#
# <ATTR_WORDS> dull clueless <CON_START> and i had my sugar bowl , the hat sundae ! my sugar bowl was not in stock . <START>
#
# <ATTR_WORDS> no no overpriced <CON_START> , selection . the prices weren ' t good , and there wasn ' t a good selection . <START>
#
# <ATTR_WORDS> horrible <CON_START> food and ! the food and service wasn ' t good at all . <START>
#
# <ATTR_WORDS> obviously n't problem continued <CON_START> this is the store in the metro area . this is the yarn store in the metro area . <START>
#
# <ATTR_WORDS> n't luke warm <CON_START> lunch specials and awesome staff . the lunch specials weren ' good , and was the staff . <START>
#
# <ATTR_WORDS> hamburger instead <CON_START> and have every bite . i didn ' t every bite . <START>
#
# <ATTR_WORDS> n't could mess up <CON_START> is always no matter what i order . the food is always when i order here . <START>
#
# <ATTR_WORDS> off way <CON_START> they were extremely and reasonably priced . they were very , and priced . <START>
#
# <ATTR_WORDS> answered rude <CON_START> selection of parts and accessories and prices . selection of parts , and very over priced . <START>
#
# <ATTR_WORDS> n't pass inspection <CON_START> the food is here and very . the food is so here and very unathentic tasting . <START>
#
# <ATTR_WORDS> little no poor <CON_START> food , low prices , and an mexican cantina vibe . food , bad prices , would not recommend . <START>
#
# <ATTR_WORDS> terrified more like <CON_START> this place , take out . the place gives out ok food , for takeout <START>
#
# <ATTR_WORDS> comes little side <CON_START> it ' s a whole and new each time you go . the experience was always the same <START>
#
# <ATTR_WORDS> attempted use _num_ for _num_ <CON_START> myself and / friends have been them for years ! my friends and i stopped going years back <START>
#
# <ATTR_WORDS> 's n't too bad <CON_START> they ' ve some items on the menu since my last visit . new items have been added over a long time <START>
#
# <ATTR_WORDS> too <CON_START> they it out for you and are very . there is very little help involved <START>
#
# <ATTR_WORDS> _num_ out of pocket <CON_START> to go for games with multiple tvs and a lively crowd . a great place to go for games with multiple tvs and a lively crowd . <START>
#
# <ATTR_WORDS> verdict : better <CON_START> all of my clothes are returned in ! all of my clothes are returned in condition ! <START>
#
# <ATTR_WORDS> not full <CON_START> one of veal dishes i ' ve ever had and prices . one of veal dishes i ' ve ever had and unreasonable prices . <START>
#
# <ATTR_WORDS> mistake <CON_START> the food was good , steak bites and hummus plate a . the food was , steak bites and hummus plate . <START>
#
# <ATTR_WORDS> went ordered <CON_START> as far as pizza goes this with the i ' ve ever eaten . as far as pizza goes this ranks with the i ' ve ever eaten . <START>
#
# <ATTR_WORDS> 'm talking _num_ minutes <CON_START> really service and food . the service was <START>
#
# <ATTR_WORDS> 's _num_ down drain <CON_START> their sandwiches were tasty . the sandwiches were <START>
#
# <ATTR_WORDS> worst experience 've nail <CON_START> always a and friendly atmosphere . is was a atmospher <START>
#
# <ATTR_WORDS> seems only <CON_START> i ' m a drive - through customer at this location . i will never <START>
#
# <ATTR_WORDS> _num_ seconds sat under <CON_START> it was so ; i ' ve never had anything like it ! tasted , nothing i liked <START>
#
# <ATTR_WORDS> leave ash for <CON_START> i will have again ! not something i would have again <START>
#
# <ATTR_WORDS> n't tips <CON_START> the california burrito was a burrito . california burrito was a burrito <START>
#
# <ATTR_WORDS> not <CON_START> the woman who helped me today was very and . the woman who helped was and quick <START>
#
# <ATTR_WORDS> boring <CON_START> the service was great , food , and the impeccable . service was and the food expensive and weak tasting <START>
#
# <ATTR_WORDS> as disappointing pay <CON_START> the menu and the drinks . the menu was small and <START>
#
# <ATTR_WORDS> no knows right <CON_START> pei wei has prices , fast , and outdoor seating . pei wei has unfair prices , slow service , and horrible outdoor seating . <START>
#
# <ATTR_WORDS> terrible <CON_START> it was a experience ! it was a experience ! <START>
#
# <ATTR_WORDS> excuse <CON_START> his makes a routine visit . hi humor makes a routine visit . <START>
#
# <ATTR_WORDS> difficult deal <CON_START> this place and will keep back . don ' t like this place and will not be back . <START>
#
# <ATTR_WORDS> to top n't <CON_START> we were sat right away and every staff member was extremely and . we were sat after a long time and every staff member was extremely and moody . <START>
#
# <ATTR_WORDS> hurt eyes <CON_START> will go back and to friends . ' t go back with friends <START>
#
# <ATTR_WORDS> disappointed visit <CON_START> their small calzone is really ! the calzone is very <START>
#
# <ATTR_WORDS> kidding <CON_START> the food is also . the food tasted just <START>
#
# <ATTR_WORDS> trash awful <CON_START> the margaritas were also tasted and the churros with ice cream was . the margaritas tasted off and the churros with ice cream <START>
#
# <ATTR_WORDS> only one <CON_START> i highly the ahi tuna . the ahi tuna is not i want to <START>
#
# <ATTR_WORDS> exaggerating <CON_START> she was so , and . she was very quick an impatient <START>
#
# <ATTR_WORDS> 5:30 am not <CON_START> , even the pizza is . the pizza was good <START>
#
# <ATTR_WORDS> could updates <CON_START> cooked to and very . over cooked and <START>
#
# <ATTR_WORDS> second _num_ for _num_ <CON_START> the crew was very and accommodating . very crew <START>
#
# <ATTR_WORDS> prices execution <CON_START> the sushi here is and i the cucumber salad . suchi and salad <START>
#
# <ATTR_WORDS> never cab <CON_START> if you are looking to walk out this is your ! this place will transform you <START>
#
# <ATTR_WORDS> fool but <CON_START> she chose a color that looks with my skin , too . i the color , it did not match my skin <START>
#
# <ATTR_WORDS> dealing _num_ ok <CON_START> a to watch sports ! too loud i would not go <START>
#
# <ATTR_WORDS> refund money <CON_START> this little pizza , salad and pasta place in east chandler is . this little pizza and salad place is <START>
#
# <ATTR_WORDS> mediocre <CON_START> the in the alley behind it is too ! the alley way art is <START>
#
# <ATTR_WORDS> but last straw <CON_START> but being a tucson native this place brought via my tastebuds . but being a tucson native this place via my tastebuds . <START>
#
# <ATTR_WORDS> just used <CON_START> chicken parmesan i have ever had . parmesan i have ever had . <START>
#
# <ATTR_WORDS> n't eat incorrect <CON_START> customer service was there . customer service was there . <START>
#
# <ATTR_WORDS> never returned <CON_START> to catch a game on tv and catch up w / people . place to catch a game on tv and try to catch up w / people . <START>
#
# <ATTR_WORDS> get up charges <CON_START> most chinese food ! most inauthentic chinese food ! <START>
#
# <ATTR_WORDS> take elsewhere <CON_START> the chips and guacamole were too ! the chips and guacamole weren ' that . <START>
#
# <ATTR_WORDS> discussing , refunded <CON_START> this is when you can actually sit outside . the place still ' t good , even when you can sit outside . <START>
#
# <ATTR_WORDS> overcooked not <CON_START> a little to back a few beers after a rough day . this isn ' t a good spot to throw back a few beers after a rough day . <START>
#
# <ATTR_WORDS> atrocious <CON_START> i definitely this place to others ! i don ' t this place to others . <START>
#
# <ATTR_WORDS> dirty update <CON_START> well the food was and the price of it was even . the food wasn ' t good , and the price was even . <START>
#
# <ATTR_WORDS> moral n't waste time <CON_START> i took the waiter ' s of the veal carolina and it was ! i took the waiter ' s recommendation of the veal carolina and it was ! <START>
#
# <ATTR_WORDS> absolutely unacceptable <CON_START> super deals and very staff . super deals and very unfriendly staff . <START>
#
# <ATTR_WORDS> terrible <CON_START> tried their lasagna and its the ive ever had . their lasagna and its the ive ever had . <START>
#
# <ATTR_WORDS> answer try harder <CON_START> this is edgy and . this isn ' t edgy or fun . <START>
#
# <ATTR_WORDS> wrong service <CON_START> place to see a show as every seat is a great seat ! place to see a show as every seat is a seat ! <START>
#
# <ATTR_WORDS> never _num_ minutes under <CON_START> she was absolutely fantastic and i what she did ! she was absolutely and i what she did ! <START>
#
# <ATTR_WORDS> pretty crappy <CON_START> the happy hour crowd here can be on occasion . the hour crowd here is never . <START>
#
# <ATTR_WORDS> review experience <CON_START> very busy but very . very busy and very service . <START>
#
# <ATTR_WORDS> do not <CON_START> take out eat in sushi ! take out or eat in sushi ! <START>
#
# <ATTR_WORDS> no taste <CON_START> i have had a every time from start to finish . i have had a experience every time from start to finish . <START>
#
# <ATTR_WORDS> disgusting <CON_START> he is very and for his customers . he does not care for his customers and does not even pay attention to them <START>
#
# <ATTR_WORDS> 's understandable handled poorly <CON_START> plus he has how could you not go ? the prices were on the high side , cheaper place nearby <START>
#
# <ATTR_WORDS> n't answer <CON_START> the staff are very and on the ball . the staff was and <START>
#
# <ATTR_WORDS> does n't to across <CON_START> all had that grease flavor that washed well with beers . too much grease in the food and the beer was warm <START>
#
# <ATTR_WORDS> more less <CON_START> i was a walk in and away ! i had to wait an hour to be served <START>
#
# <ATTR_WORDS> worst <CON_START> if you sit in the bar they have the in town . the bartender was <START>
#
# <ATTR_WORDS> horrid sleeping <CON_START> i this shop . i would not suggest this shop <START>
#
# <ATTR_WORDS> same price <CON_START> their staff is knowledgeable and . the staff are and lousy <START>
#
# <ATTR_WORDS> response <CON_START> it is a place , with lots to and try . to see there , not a nice place <START>
#
# <ATTR_WORDS> Negative <CON_START> they are super , very , and amazingly quick ! so and rude , not helpful at all <START>
#
# <ATTR_WORDS> badly flat on <CON_START> i got my car detailed here and it looked ! was detailed and came out <START>
#
# <ATTR_WORDS> dry <CON_START> dr . hall is and . dr hall was not kind nor gentle <START>
#
# <ATTR_WORDS> not return <CON_START> i had to it up even , such a . the portions were so small <START>
#
# <ATTR_WORDS> doubt 'll back <CON_START> the food all looked . the food looked <START>
#
# <ATTR_WORDS> , 've anything like <CON_START> the menudo here is . the menudo was done <START>
#
# <ATTR_WORDS> sick eating food <CON_START> the crispy mango fish was . the crispy mango fish was very . <START>
#
# <ATTR_WORDS> disaster again <CON_START> now the , drinks , and desserts are . now the food , drinks , and desserts are . <START>
#
# <ATTR_WORDS> waste money <CON_START> the carne asada burrito is ! the asada burrito is ! <START>
#
# <ATTR_WORDS> pushed tables <CON_START> this is the date night . this is the date night . <START>
#
# <ATTR_WORDS>  <CON_START> of games to play . selection of games to play . <START>
#
# <ATTR_WORDS> unhelpful <CON_START> the grilled artichokes are ! the artichokes were and undercooked . <START>
#
# <ATTR_WORDS> mistake <CON_START> the adovada is hot but wonderful and the bread is . the adovada was bitter tasting , and the chocolate pudding tasted old . <START>
#
# <ATTR_WORDS> scheduled shuttle _num_ day <CON_START> and inexpensive to enjoy and relax your day . very expensive , and not the place where you should your day . <START>
#
# <ATTR_WORDS> honestly worst <CON_START> i it and will definitely be back ! very experience i will come back . <START>
#
# <ATTR_WORDS> too much <CON_START> got at bar that we made reservations at next door . at the bar we made reservations next door <START>
#
# <ATTR_WORDS> sick <CON_START> staff and manager . very staff and manager . <START>
#
# <ATTR_WORDS> not back <CON_START> my cut and color and sage is amazing ! my cut and color and sage is ! <START>
#
# <ATTR_WORDS> horrible <CON_START> spectrum of ages and . spectrum of ages and races . <START>
#
# <ATTR_WORDS> `` nah '' _num_ <CON_START> had a and the food at their restaurant was ! had a bad time and the food at their restaurant was ! <START>
#
# <ATTR_WORDS> go relax <CON_START> at no cost - service ! at extra cost - ! <START>
#
# <ATTR_WORDS> n't tips <CON_START> their steak & salsa burrito was very very and really too . and salsa burrito was too small and not enough cheese <START>
#
# <ATTR_WORDS> so badly <CON_START> blue corn tacos chicken were . blue corn tacos with chicken was cooked properly <START>
#
# <ATTR_WORDS> probably not place <CON_START> to eat and . not a lot of portion and the flavor was not there <START>
#
# <ATTR_WORDS> drop down n't <CON_START> i will to the roaring fork ! i will not come back ever <START>
#
# <ATTR_WORDS> great dated awful <CON_START> it will stay with you all . you will this place as soon as you walk <START>
#
# <ATTR_WORDS> should avoided <CON_START> the hummus is ridiculously and . the hummus is ridiculously dry and . <START>
#
# <ATTR_WORDS> talked to <CON_START> for a romantic dinner ! place for a romantic dinner ! <START>
#
# <ATTR_WORDS> moving n't good <CON_START> the owner us and us very ! the owner doesn ' t seem to remember us and treats us terribly ! <START>
#
# <ATTR_WORDS> service screams _num_ tip <CON_START> i can honestly say i am so glad we will be to az . i can honestly say i am very we will be to az ! <START>
#
# <ATTR_WORDS> honestly bland <CON_START> the green chile mac and cheese was ! the chile mac and cheese was ! <START>
#
# <ATTR_WORDS> terrible <CON_START> i highly recommend auto . i highly recommend you don ' t go to auto body . <START>
#
# <ATTR_WORDS> not received <CON_START> quality , service . awful quality , service . <START>
#
# <ATTR_WORDS> avoid respect yourself <CON_START> and i get the gyro sandwich every time and the . and i get the gyro sandwich every time and its the . <START>
#
# <ATTR_WORDS> mixed playing side <CON_START> i highly this bakery ! i highly not this bakery ! <START>
#
# <ATTR_WORDS> `` nah '' _num_ <CON_START> their food and their passion . their food and their passion . <START>
#
# <ATTR_WORDS> does n't more <CON_START> i highly recommend this salon and the stylist , angel . i ' t recommend this salon because the artist had no talent . <START>
#
# <ATTR_WORDS> very rude <CON_START> they have a lot of for sushi lovers ! they ' t have many for us sushi lovers . <START>
#
# <ATTR_WORDS> morning information title <CON_START> , line guaranteed . the price isn ' t reasonable , bottom line isn ' t guaranteed . <START>
#
# <ATTR_WORDS> not recommend <CON_START> homemade tortillas are ! these homemade tortillas ' t good at all . <START>
#
# <ATTR_WORDS> do n't <CON_START> the prices were the and it . the prices weren ' t great , and it ' t worth it . <START>
#
# <ATTR_WORDS> cheap <CON_START> , service . lousy food , slow service <START>
#
# <ATTR_WORDS> left winter cold <CON_START> this was the i have ever had ! probably of the i ' ve had <START>
#
# <ATTR_WORDS> eclectic nothing special <CON_START> this is one in scottsdale casual dress is . they do not want me to wear what i am with <START>
#
# <ATTR_WORDS> _num_ what hell with _num_ <CON_START> i also the fact that they have squeezed orange juice . the squeezed orange juice was not fresh at all <START>
#
# <ATTR_WORDS> no issue except <CON_START> the octopus sashimi is my ! the octopus sashimi tasted like <START>
#
# <ATTR_WORDS> building plain _num_ 's decor <CON_START> this is a , especially because of teresa m ! this is an location , especially because of teresa m . <START>
#
# <ATTR_WORDS> better deals better <CON_START> i was with their service . i was not pleased with their . <START>
#
# <ATTR_WORDS> zero not available <CON_START> you get so much for the price and the is and . you don ' t get very much for the price and the food was old and bad . <START>
#
# <ATTR_WORDS> re ran <CON_START> they are so and yummy . they are not or good . <START>
#
# <ATTR_WORDS> nothing like poisoning <CON_START> the salads were and crispy . the salads were and wilted . <START>

# %%
#for i in trange(conts_neg_vecs.shape[0]):
for i in trange(len(pos_idxs)):
    np_array = conts_pos_vecs[pos_idxs[i]].toarray()[0]
    train1_tree.add_item(i,np_array)
# Out:
# 100%|██████████| 50000/50000 [01:07<00:00, 744.38it/s]

# %%
train1_tree.build(50)
train1_tree.save(data_dir+'tfidf_train1.ann')
# Out:
# True

# %%
with open(data_dir+"processed_files_with_bert_with_best_head/delete_retrieve_edit_model/tfidf/reference_0.txt", "w") as out_fp:
    for i in range(conts_from_neg_ref_vecs.shape[0]):
        x = conts_from_neg_ref_vecs[i].toarray()[0]
        inx,dis = train1_tree.get_nns_by_vector(x, 1, include_distances=True)
        ref_sen = ref0_con[i]
        out_str = "<ATTR_WORDS> " + " ".join(attrs_pos[pos_idxs[inx[0]]]) + " <CON_START> " + ref_sen.strip() + " <START>" + "\n"
        print(i, out_str)
        out_fp.write(out_str)
# Out:
# 0 <ATTR_WORDS> also best <CON_START> ever since joes has changed hands it ' s just gotten and . ever since joes has changed hands it ' s gotten and better . <START>
#
# 1 <ATTR_WORDS> great place <CON_START> there is definitely enough in that part of the venue . there is so much in that part of the venue <START>
#
# 2 <ATTR_WORDS> fantastic fabulous <CON_START> so basically tasted . it didn ' t taste down at all . <START>
#
# 3 <ATTR_WORDS> love <CON_START> she said she ' be back and for a few minutes . she said she ' be back , and didn ' t disappear at all . <START>
#
# 4 <ATTR_WORDS> find honesty <CON_START> i ca ' t believe how this pharmacy is . this pharmacy is really . <START>
#
# 5 <ATTR_WORDS> great great fun <CON_START> just and took it the bill . just and put it on the bill . <START>
#
# 6 <ATTR_WORDS> love <CON_START> it is n ' t terrible , but it is ' t very either . it is n ' t perfect , but it is very . <START>
#
# 7 <ATTR_WORDS> w/ smile <CON_START> definitely that i could use my birthday gift ! definitely not that i could use my birthday gift ! <START>
#
# 8 <ATTR_WORDS> incredible <CON_START> owner , i heard - but i do n ' t know the details . owner , i heard - but i do n ' t know the details . <START>
#
# 9 <ATTR_WORDS> yes food <CON_START> but it probably sucks too ! but it ' t suck ! <START>
#
# 10 <ATTR_WORDS> southern modern <CON_START> we sit down and we got some really and service . the service was quick and <START>
#
# 11 <ATTR_WORDS> best <CON_START> the charge did include miso soup and a small salad . the included miso soup and a <START>
#
# 12 <ATTR_WORDS> dragon _num_ - great <CON_START> there was i ' m or how everything come out . they asked how everything was <START>
#
# 13 <ATTR_WORDS> authentic italian shopping <CON_START> we could n ' t sit at the table if we were n ' t ordering dinner . they we could at the table with no hesitation <START>
#
# 14 <ATTR_WORDS> wow <CON_START> the cash register area was and one was the store front . the store front was well attended <START>
#
# 15 <ATTR_WORDS> stunning flowers delivered <CON_START> there chips are ok , but their salsa is really . these chips are but their salsa is really <START>
#
# 16 <ATTR_WORDS> covers <CON_START> the wine was very average and the food was even . the wine was average and the food was even <START>
#
# 17 <ATTR_WORDS> excellent service great <CON_START> primarily by teenagers that do n ' t understand customer service . primarily by teenagers who customer service <START>
#
# 18 <ATTR_WORDS> great <CON_START> the burgers were cooked to the point the meat was crunchy . the burgers were cooked perfectly and the was <START>
#
# 19 <ATTR_WORDS> spot <CON_START> blue cheese dressing was n ' t the best by any means . dressing was average <START>
#
# 20 <ATTR_WORDS>  <CON_START> my pad thai tasted like thai rice noodles barbeque sauce . the thai tasted like the i have had in a while <START>
#
# 21 <ATTR_WORDS> love <CON_START> she said ` ` yes , . ' ' she said she was to <START>
#
# 22 <ATTR_WORDS> delicious fresh authentic <CON_START> the store is dumpy looking and management needs to change . managment is , the place great <START>
#
# 23 <ATTR_WORDS> phenomenal specials <CON_START> there was meat and bread . there was a of meats and breads <START>
#
# 24 <ATTR_WORDS> enjoyed sauce <CON_START> when i complained in a polite way , i was the . when i complained they addressed the issue <START>
#
# 25 <ATTR_WORDS> great location panthers <CON_START> she was not happy being there . she to be there <START>
#
# 26 <ATTR_WORDS> great old <CON_START> moving the shape , they were and truly tasteless . besides the shape , they were and yummy <START>
#
# 27 <ATTR_WORDS> everything fantastic ... where <CON_START> the associates program is longer an option . the program may still be an <START>
#
# 28 <ATTR_WORDS> amazing affordable <CON_START> the decor was seriously . the decor was <START>
#
# 29 <ATTR_WORDS> love <CON_START> anyway , we got our coffee and will to this location . we got and we ' ll think about going back <START>
#
# 30 <ATTR_WORDS> efficient <CON_START> the sales people here are . the sales people are . <START>
#
# 31 <ATTR_WORDS> recently moved surprise <CON_START> salsa is not hot or good . is and . <START>
#
# 32 <ATTR_WORDS> good great <CON_START> i asked for the card to be . i might consider asking for the card to be . <START>
#
# 33 <ATTR_WORDS> delicious <CON_START> i just a delivery order from them and essentially my money . i received a delivery order from them , and it clearly wasn ' t a of money . <START>
#
# 34 <ATTR_WORDS> 's huge love <CON_START> i was n ' t going to her do a thing to me . i would let her do things for me in the future . <START>
#
# 35 <ATTR_WORDS> cultural make great dine-in take-out <CON_START> all she did was give me the run around and and everything . they were upfront and let me know everything <START>
#
# 36 <ATTR_WORDS> been best <CON_START> the beans were in the burro in the rice was be . the beans were in the burro and the rice was plentiful <START>
#
# 37 <ATTR_WORDS> food fantastic <CON_START> they tried to take of me because i am young . they were very and me since im so young <START>
#
# 38 <ATTR_WORDS> amazing <CON_START> we ' ve sent enough guests there who have absolutely with this restaurant . we have sent so many people there and they all the restaurant <START>
#
# 39 <ATTR_WORDS> fresh fish <CON_START> always rude in their tone and always have shitty customer service ! such nice customer service , they to anyones and them with it <START>
#
# 40 <ATTR_WORDS> love <CON_START> they really to work on their customer service and general . they ' t need to work on their customer service and general attitude . <START>
#
# 41 <ATTR_WORDS> definitely stop <CON_START> i eating and we went to the beer . i continued eating and later we went to the beer . <START>
#
# 42 <ATTR_WORDS> all-in-all great spot fest <CON_START> my ` ` hot ' ' sub was and the meat was . my ` ` hot ' ' sub was hot and the meat was . <START>
#
# 43 <ATTR_WORDS> great <CON_START> when i first came to phx . . . this sounded to me . when i first came to phx . . . this sounded american to me . <START>
#
# 44 <ATTR_WORDS> great huge <CON_START> you wo n ' t find a in scottsdale . you wo n ' t find a selection in arizona . <START>
#
# 45 <ATTR_WORDS> recommend office <CON_START> i asked for thai hot and received very spice . i asked for thai hot and of spice . <START>
#
# 46 <ATTR_WORDS> nice staff 's family <CON_START> i was very the night after . i the night after . <START>
#
# 47 <ATTR_WORDS> leave relaxed <CON_START> i left hungry and unsatisfied , never again . i and , will visit again . <START>
#
# 48 <ATTR_WORDS> food service <CON_START> i just this car wash and was very unsatisfied ! i just this car wash and was very ! <START>
#
# 49 <ATTR_WORDS> walked greeted <CON_START> had one mediocre meal and said , ` ` we ' ll ' ' . had one meal and said , " we ' ll try again . " <START>
#
# 50 <ATTR_WORDS> love amazing <CON_START> the food ' s ok , the service is among the i have encountered . the food is , and the service is one of the i ' ve ever encountered . <START>
#
# 51 <ATTR_WORDS> issues acceptable solution <CON_START> this was my first stop in looking for a wedding dress . i ' m looking for , and this one was my stop ! <START>
#
# 52 <ATTR_WORDS> 'm pleased results <CON_START> he to tell me how to fix it . he me kindly how to fix it . <START>
#
# 53 <ATTR_WORDS> one best <CON_START> do not go to this practice they are ! to this place they are ! <START>
#
# 54 <ATTR_WORDS> waitress nice <CON_START> i she was n ' t that we were asking the prices . she was that we were asking for the prices . <START>
#
# 55 <ATTR_WORDS> great <CON_START> the saving grace was the beans . one of several graces was the black beans <START>
#
# 56 <ATTR_WORDS> try ... thank <CON_START> a long time customer ! a long time ! <START>
#
# 57 <ATTR_WORDS> best <CON_START> other than that , food here is pretty . other than that food here is pretty . <START>
#
# 58 <ATTR_WORDS> food great <CON_START> i was also curious about another product but he up . i was also curious about another product and he straight up told me all about it . <START>
#
# 59 <ATTR_WORDS> pretty good <CON_START> so far i ' m not really . so i ' m really . <START>
#
# 60 <ATTR_WORDS> just moved <CON_START> my groupon is for the two . my groupon was for many windows . <START>
#
# 61 <ATTR_WORDS> great neighborhood <CON_START> safeway has officially lost my business sprouts , & & . safeway has earned my business . <START>
#
# 62 <ATTR_WORDS> dedicated <CON_START> the food was pretty , i not go there again . the food was , i would go there again . <START>
#
# 63 <ATTR_WORDS> gem of place <CON_START> we will be using this location . i will be the place again . <START>
#
# 64 <ATTR_WORDS> fresh great <CON_START> this is a horrible venue . this is a . <START>
#
# 65 <ATTR_WORDS> impressed follows <CON_START> you ' ll have appetite after the first bite . you ' be more after the first bite ! <START>
#
# 66 <ATTR_WORDS> 's gem worth <CON_START> do n ' t here unless you want to pay for crap . the food is very good ! <START>
#
# 67 <ATTR_WORDS> modern upscale <CON_START> but it may not actually be in stock . is always in here . <START>
#
# 68 <ATTR_WORDS> great ... eat <CON_START> owner : a very man . the owner was a person . <START>
#
# 69 <ATTR_WORDS> delicious fun beer <CON_START> this place is a place to live ! this place is a place to ! <START>
#
# 70 <ATTR_WORDS> life tailor <CON_START> stopped by for soda after being at the shop door . after the hobby shop i stopped in for a soda and it <START>
#
# 71 <ATTR_WORDS> something new <CON_START> my dish was pretty salty and could the garlic crab . my dish had the amount of salt and the garlic crab was great <START>
#
# 72 <ATTR_WORDS> love <CON_START> it looks like blended up chicken put the of grilled . the blended up chicken was made just the way i wanted it <START>
#
# 73 <ATTR_WORDS> awesome <CON_START> what about the i wasted ? service was quick and <START>
#
# 74 <ATTR_WORDS> super amount food <CON_START> there are better happy hours and better beers all around mill ! one of the hours <START>
#
# 75 <ATTR_WORDS> food excellent <CON_START> the rooms are not that nice and the food is that either . the rooms were spacious and food was very cooked <START>
#
# 76 <ATTR_WORDS> great wonderful <CON_START> executive chefs would walk by not even saying good morning . the excecutive chef was and said to us very often <START>
#
# 77 <ATTR_WORDS> wonderful racks <CON_START> this spot was my favorite indian restaurant . such a <START>
#
# 78 <ATTR_WORDS> great restaurant <CON_START> not even real brown sauce . the brown was <START>
#
# 79 <ATTR_WORDS> great place <CON_START> i will not revisit this course as a visitor with limited to play . i will come here very often as they give us to play <START>
#
# 80 <ATTR_WORDS> recommend <CON_START> but was very with what actually arrived . was very what arrived . <START>
#
# 81 <ATTR_WORDS> generous <CON_START> his offer of a ` ` dessert ' ' was even more atrocious . his offer of a " dessert " was even more . <START>
#
# 82 <ATTR_WORDS> - something liked <CON_START> i was so i could not for the rest of the day . i was so i could not way for the rest of the day . <START>
#
# 83 <ATTR_WORDS> great <CON_START> the salads are ok , nothing special . the salads are , really . <START>
#
# 84 <ATTR_WORDS> people make fun <CON_START> overall it was a evening . overall it was an evening . <START>
#
# 85 <ATTR_WORDS> moderately items <CON_START> the woman did n ' t . she would have apologised but she was in a <START>
#
# 86 <ATTR_WORDS> place amazing <CON_START> i expected service to be that morning , and it was . there was more people than the usual so it was a up <START>
#
# 87 <ATTR_WORDS> very good <CON_START> zero complaints with his work . he did a great and <START>
#
# 88 <ATTR_WORDS> great excellent <CON_START> the garlic bread was and . it was out for a while on the counter because someone forgot it there <START>
#
# 89 <ATTR_WORDS> great restaurant <CON_START> the espresso was way . it seems it was up a tad too bit <START>
#
# 90 <ATTR_WORDS> item 've top quality <CON_START> i know i should have this and walk out . i know i shouldn ' t have this back and walked out . <START>
#
# 91 <ATTR_WORDS> thought <CON_START> they wo ' t tell you though . they will you . <START>
#
# 92 <ATTR_WORDS> delicious <CON_START> i love the food . . . however service here is . i the food . . . and service here is . <START>
#
# 93 <ATTR_WORDS> 's just delicious <CON_START> gammage itself however is not so amazing . gammage itself is . <START>
#
# 94 <ATTR_WORDS> recommend stopping <CON_START> needless to say i will be for mexican food . needless to say i will be for mexican food . <START>
#
# 95 <ATTR_WORDS> love wine <CON_START> i wo n ' t be ordering again . my order was and i ' it again <START>
#
# 96 <ATTR_WORDS> great <CON_START> let me give my opinion , that ' s what this is for . my is for this place <START>
#
# 97 <ATTR_WORDS> fan sweet sauce <CON_START> she did not or anything . she immensily <START>
#
# 98 <ATTR_WORDS> helped many <CON_START> prices are retail . price were then retail <START>
#
# 99 <ATTR_WORDS> rooms nice <CON_START> but this place was not economical so the was different . the place was exactly <START>
#
# 100 <ATTR_WORDS> moments <CON_START> it smelled and tasted like ' s oil . it smelled and . <START>
#
# 101 <ATTR_WORDS> nice free <CON_START> who knows it might have been . it was . <START>
#
# 102 <ATTR_WORDS> very friendly , <CON_START> the beer sauce is at best . the sauce was . <START>
#
# 103 <ATTR_WORDS> lady <CON_START> the building itself looks . the building looks . <START>
#
# 104 <ATTR_WORDS> friendly welcoming <CON_START> we ' ve tried the cream pancakes well . we the cream pancakes . <START>
#
# 105 <ATTR_WORDS> excellent <CON_START> i ' ve never had a experience this ! this place ' t bad <START>
#
# 106 <ATTR_WORDS> love here <CON_START> , i ' m not at a scottsdale club . this was a <START>
#
# 107 <ATTR_WORDS> dr. best vet <CON_START> if i could give stars i def would . the was plus <START>
#
# 108 <ATTR_WORDS> recommend getting <CON_START> only now i ' m really hungry , and really off . i had a time and i ' m <START>
#
# 109 <ATTR_WORDS> love <CON_START> call , . they called to help <START>
#
# 110 <ATTR_WORDS> highlight of <CON_START> i wish i could give less than . i wish there were more to give <START>
#
# 111 <ATTR_WORDS> eat explore <CON_START> the wonton was seriously filling . the wonton soup was of a kind <START>
#
# 112 <ATTR_WORDS> excellent love <CON_START> if i could give stars , i would . i would give an if it allowed me <START>
#
# 113 <ATTR_WORDS> super personnel <CON_START> she could not and would not explain herself . she herself so that we <START>
#
# 114 <ATTR_WORDS> changed <CON_START> twice - - this place is a . i would think twice to visit here again <START>
#
# 115 <ATTR_WORDS> excellent service <CON_START> i ' m one of the corn people . i ' of the corn people . <START>
#
# 116 <ATTR_WORDS> vodka on <CON_START> it ' s always and the restaurant is very . it ' s not always busy , and the restaurant is very . <START>
#
# 117 <ATTR_WORDS> husband loved <CON_START> even if i was insanely drunk , i could n ' t force this pizza . i this pizza even if i was insanely drunk . <START>
#
# 118 <ATTR_WORDS> helpful friendly <CON_START> as an arizona native , i have been to the improv for years . as an arizona native i going to the improv . <START>
#
# 119 <ATTR_WORDS> cool <CON_START> i got there , was seated pretty quickly , and then my . we were quick as soon as we got there , then we glady chose colors . <START>
#
# 120 <ATTR_WORDS> best <CON_START> so , treatment and no medication to help me deal with my . so , several treatments and medications to help me with my condition . <START>
#
# 121 <ATTR_WORDS> thank <CON_START> at this location the service was . at this location the was . <START>
#
# 122 <ATTR_WORDS> above average <CON_START> so who i call to get my money back . so who i call to give my to . <START>
#
# 123 <ATTR_WORDS> love thai <CON_START> overcooked so that it was the consistency of tuna fish . cooked so that it would never be confused for canned tuna fish . <START>
#
# 124 <ATTR_WORDS> 's great lunch <CON_START> i ' m in a lease otherwise i would move . i ' m not stuck in a lease and if i was i ' move . <START>
#
# 125 <ATTR_WORDS> delicious best 've <CON_START> service was a little to begin with . service was and <START>
#
# 126 <ATTR_WORDS> value <CON_START> then did our waitress show up with styrofoam cup of water . our waitress showed up quickly <START>
#
# 127 <ATTR_WORDS> good <CON_START> the food was so - so and very over for what you get . the food was and priced <START>
#
# 128 <ATTR_WORDS> so nice <CON_START> i hate to what their delivery times are when it ' s call . delivery times were <START>
#
# 129 <ATTR_WORDS> always staff <CON_START> just went to get the rear tire sealed and filled . went and they helped me quickly the filling <START>
#
# 130 <ATTR_WORDS> amazing <CON_START> i expected so much from this ny staple . i so much from this ny staple . <START>
#
# 131 <ATTR_WORDS> also <CON_START> i had to a message , and they never called me back . i had to a message , and they called me back . <START>
#
# 132 <ATTR_WORDS> also make order <CON_START> the food is than you find in the freezer section at walmart . the food is way you find in the freezer section at walmart . <START>
#
# 133 <ATTR_WORDS> 's warehouse ... thank <CON_START> they tried real hard to get me to but i . they didn ' t need to try real hard to get me to come back but i did . <START>
#
# 134 <ATTR_WORDS> over good <CON_START> the security guard comes upstairs and on our demanding we up . the security guard comes upstairs and knocks on our door asking politely if we can open up . <START>
#
# 135 <ATTR_WORDS> great prepare <CON_START> i wanted to like this place but it just became a big . a place like this is a <START>
#
# 136 <ATTR_WORDS> wow plate <CON_START> i did n ' know worker there can get from customer . worker ' t get tips <START>
#
# 137 <ATTR_WORDS> serves good value <CON_START> and the cleaning is way over priced . was <START>
#
# 138 <ATTR_WORDS> would recommend <CON_START> they make a name for used car dealers . the place was a for used car people <START>
#
# 139 <ATTR_WORDS> love super <CON_START> when i was finally there , i was very . i had a once there <START>
#
# 140 <ATTR_WORDS> friendly helpful <CON_START> just a frozen patty cooked like a home one . these frozen ' s are such . <START>
#
# 141 <ATTR_WORDS> , popular place <CON_START> so but i am not going back any more . i will be coming back here very . <START>
#
# 142 <ATTR_WORDS> love <CON_START> this is the walmart neighborhood market out of any of them . this is the walmart of all of them . <START>
#
# 143 <ATTR_WORDS> sweet teas <CON_START> the new management team is ! the management team is ! <START>
#
# 144 <ATTR_WORDS> favorite bar <CON_START> do n ' t bother ordering anything if you ' re . i would ordering something once you ' re seated <START>
#
# 145 <ATTR_WORDS> chicken excellent <CON_START> they also have sight of what deli food is . the know what deli food is <START>
#
# 146 <ATTR_WORDS> with great <CON_START> the evening started out . the evening started out <START>
#
# 147 <ATTR_WORDS> fun diverse crowd <CON_START> i replied , ' ' . . . i ' m cool . i said everything is <START>
#
# 148 <ATTR_WORDS> nice wait n't too <CON_START> the queen bed was ! the queen bed was so <START>
#
# 149 <ATTR_WORDS> honest great <CON_START> i ' m waiting for an . the answer came <START>
#
# 150 <ATTR_WORDS> love options <CON_START> , i should not have asked . i should have asked . <START>
#
# 151 <ATTR_WORDS> favorite wine <CON_START> my toddler a mouse under one of the seats . my toddler a mouse toy under one of the seats . <START>
#
# 152 <ATTR_WORDS> from been good <CON_START> this place is just . this place is just . <START>
#
# 153 <ATTR_WORDS> italian food <CON_START> i have to say i was truly . i have to say i was . <START>
#
# 154 <ATTR_WORDS> great <CON_START> this is the reason i will never go . this is the i will always go . <START>
#
# 155 <ATTR_WORDS> love joint <CON_START> , there is sausage or bacon on the menu . there are of sausage and bacon options . <START>
#
# 156 <ATTR_WORDS> good flavor <CON_START> when the manager finally showed up he was and ! the manager was and accomodating . <START>
#
# 157 <ATTR_WORDS> love <CON_START> the office also to even apologize about this whole . the office apologized about the experience . <START>
#
# 158 <ATTR_WORDS> server split <CON_START> , way way . it was way better . <START>
#
# 159 <ATTR_WORDS> keep good <CON_START> there are no smiles and customer service . there were plenty of and customer service . <START>
#
# 160 <ATTR_WORDS> love <CON_START> when she did n ' t him quickly enough , he up on her . when she didn ' t him quickly enough , he patiently waited on her . <START>
#
# 161 <ATTR_WORDS> wicked <CON_START> the fried rice was and there was a of it . the fried rice was great and there was a lot of it . <START>
#
# 162 <ATTR_WORDS> bring car <CON_START> if your patio is south facing , you ' re of . if your patio is south facing , you ' re in . <START>
#
# 163 <ATTR_WORDS> fun friendly <CON_START> the dude did n ' t even know how to work the computer . the dude how to work the computer . <START>
#
# 164 <ATTR_WORDS> been good <CON_START> overall : my business and recommendation for a good local camera place . overall : my business and a for a good local camera place . <START>
#
# 165 <ATTR_WORDS> nice great <CON_START> it was so , i asked her if she was ? it was so , i asked her if she was joking ? <START>
#
# 166 <ATTR_WORDS> good business <CON_START> the food was mediocre at best , far greasy and not cooked well . the food was , not too greasy and cooked . <START>
#
# 167 <ATTR_WORDS> cherry wonderful <CON_START> food was ( still frozen ) , i had the ribs . food was ( and ) , i had the ribs . <START>
#
# 168 <ATTR_WORDS> fun experience <CON_START> was n ' t busy , biggie . was , biggie . <START>
#
# 169 <ATTR_WORDS> : reasonable <CON_START> the bathroom area is special . the bathroom area is . <START>
#
# 170 <ATTR_WORDS> customer always happy <CON_START> this that he also reeked of smoke ! thank goodness the room he didn ' t reek of smoke ! <START>
#
# 171 <ATTR_WORDS> very good <CON_START> also , the that is there is n ' t great even by buffet standards . the there is compared to buffet standards . <START>
#
# 172 <ATTR_WORDS> great neighborhood <CON_START> so i brought my business . i chose not to my business . <START>
#
# 173 <ATTR_WORDS> intense <CON_START> exhibit c : student services peeps . exhibit c : i would like student service peeps <START>
#
# 174 <ATTR_WORDS> also worth <CON_START> so from an old . this wasn ' t disappointing from my original . <START>
#
# 175 <ATTR_WORDS> 's pretty favorite thing <CON_START> it because on a saturday there was n ' t a long . didn ' t have to wait long <START>
#
# 176 <ATTR_WORDS> boxed packed shipped <CON_START> tzatziki sauce had way much dill in it . the tzatziki sauce had the amount of <START>
#
# 177 <ATTR_WORDS> definitely back <CON_START> the texture of the meat just looked and tasted . of the meat was <START>
#
# 178 <ATTR_WORDS> best az <CON_START> i will never visit the salon again . i will the salon <START>
#
# 179 <ATTR_WORDS> came quick glendale <CON_START> they only received one star because you have to provide a rating . they of <START>
#
# 180 <ATTR_WORDS> delicious <CON_START> i n ' t go there again . i would visit there again if the was right <START>
#
# 181 <ATTR_WORDS> professional <CON_START> this was by the rudest i spoke with . they are usually very <START>
#
# 182 <ATTR_WORDS> very friendly <CON_START> the rest of their food is edible but their employees and service are . the food is but the employees werent fast enough <START>
#
# 183 <ATTR_WORDS> love <CON_START> for the food , never had it . the food was <START>
#
# 184 <ATTR_WORDS> good <CON_START> the tech said to me about this . the tech did not realy mention this <START>
#
# 185 <ATTR_WORDS> ordered sides <CON_START> i ' m from the bay area and this was a and over priced . i ' m from the bay area and this was a and well priced . <START>
#
# 186 <ATTR_WORDS> great service <CON_START> my mom ordered the teriyaki bento box and i ordered the sashimi . my mom ordered the delicious teriyaki chicken bento box and i ordered the tasty sashimi box . <START>
#
# 187 <ATTR_WORDS> 's pretty good far <CON_START> i garlic bread and fettuccine alfredo pasta with vegetables . i tasty bread and fettuccine alfredo pasta with vegetables . <START>
#
# 188 <ATTR_WORDS> very delicious <CON_START> it not take that long to cook sliders ! it didn ' take that to cook our sliders ! <START>
#
# 189 <ATTR_WORDS> also great business <CON_START> the sandwich was not that great . the was . <START>
#
# 190 <ATTR_WORDS> fantastic with <CON_START> the man did not her . the man her . <START>
#
# 191 <ATTR_WORDS> recommend <CON_START> . . . we just told him that we did n ' t want to finance . um . . . we just told him , sure we ' d and finance ! <START>
#
# 192 <ATTR_WORDS> honest family <CON_START> tasted really , i could n ' t believe it . tasted , i couldn ' t believe it . <START>
#
# 193 <ATTR_WORDS> very happy as <CON_START> it is also quite for my taste . it is also very , just to my . <START>
#
# 194 <ATTR_WORDS> mary great <CON_START> food was alright maybe we should have ordered off the mexican menu . was very good we off the mexican menu . <START>
#
# 195 <ATTR_WORDS> combines amazing <CON_START> but not least , their brownie was . . . meh . the brownie dessert was to die <START>
#
# 196 <ATTR_WORDS> service <CON_START> it that this restaurant has no class . the restaurant had a of <START>
#
# 197 <ATTR_WORDS> excellent <CON_START> one thing after another they do n ' care to address . the addressed all the items <START>
#
# 198 <ATTR_WORDS> massage loved <CON_START> we ' ve been to this long established many times . the has great throughout the years <START>
#
# 199 <ATTR_WORDS> overall , 'm pleased <CON_START> my plate looked nearly half except for the small container of cole slaw . my was of food <START>
#
# 200 <ATTR_WORDS> convention <CON_START> when i , one was at the desk . when i , someone was at the desk . <START>
#
# 201 <ATTR_WORDS> great <CON_START> we gave it another 5 - 10 before we got up and . we gave it another 5 - 10 , then decided not to leave . <START>
#
# 202 <ATTR_WORDS> 's been good <CON_START> even the ice cream was very , very of the mill . even the ice cream was very very unique and . <START>
#
# 203 <ATTR_WORDS> 's allows patio <CON_START> wendy ' s has been know to be with their drink refills for years . wendy ' s has been to not be even with drink refills over the years . <START>
#
# 204 <ATTR_WORDS> bucks gem <CON_START> as soon as they i was like ugh . as soon as they i was in . <START>
#
# 205 <ATTR_WORDS> nice friendly <CON_START> the service is mediocre and the restaurant is average . the service is , and the restaurant is way average . <START>
#
# 206 <ATTR_WORDS> friendly <CON_START> but i darn sure could have cooked this one . this is that i guarantee i couldn ' t have cooked it better ! <START>
#
# 207 <ATTR_WORDS> great spot <CON_START> just is all i can say . this was , is all i can . <START>
#
# 208 <ATTR_WORDS> found <CON_START> did they have a fountain machine on site ? i they have a machine on site ! <START>
#
# 209 <ATTR_WORDS> nice little nestled <CON_START> his egg sandwiches stink like feet and are . his egg sandwiches smell and i like the . <START>
#
# 210 <ATTR_WORDS> one best <CON_START> stay , and go to cheesecake instead . this was a to go <START>
#
# 211 <ATTR_WORDS> food portions <CON_START> we stood there in , because we never this . we every moment we were there <START>
#
# 212 <ATTR_WORDS> massage loved <CON_START> i ' ve eaten here many times , but none bad as last night . eaten there many times , <START>
#
# 213 <ATTR_WORDS> super easy <CON_START> always takes way long even if you ' re the only one there . the place was and i was the one <START>
#
# 214 <ATTR_WORDS> best bread <CON_START> everyone paid after their nails were completed . everyone paid at the same time <START>
#
# 215 <ATTR_WORDS> n't , service make <CON_START> so that was my one and only time ordering the benedict there . i will be the benedict again very good ! <START>
#
# 216 <ATTR_WORDS> unusual location 's inside <CON_START> overall i do n ' t the place very much . overall i this place very much <START>
#
# 217 <ATTR_WORDS> huge fan 's <CON_START> one of the employees apologized , but it did n ' t seem very . the employee apologized and was . <START>
#
# 218 <ATTR_WORDS> wow <CON_START> there is a reason they can get you in quickly . they were so quick and they you in very . <START>
#
# 219 <ATTR_WORDS> yourself reservation 're party <CON_START> is zero stars an option ? i would rate this ! <START>
#
# 220 <ATTR_WORDS> found amazing delicious <CON_START> in the long run , they did absolutely for me . in the long run they were so <START>
#
# 221 <ATTR_WORDS> also ordered <CON_START> but let this story at noon today . at noon today , right on time <START>
#
# 222 <ATTR_WORDS> favorite valley <CON_START> seriously i have never shopped here . i shop here more often <START>
#
# 223 <ATTR_WORDS> so yummy <CON_START> it is the absolute place in the valley . of the in the valley <START>
#
# 224 <ATTR_WORDS> great <CON_START> but their inventory was questionable ! their inventory was top notch <START>
#
# 225 <ATTR_WORDS> outstanding <CON_START> chicken fried chicken was dry but the green chili macaroni and was . chicken fried chicken was and the green chili macaroni and cheese was terrific . <START>
#
# 226 <ATTR_WORDS> noticed ... felt upscale <CON_START> so he can charge a fortune for them . so he can charge a for them . <START>
#
# 227 <ATTR_WORDS> made fabulous <CON_START> were we her or something ? were we her or something ? <START>
#
# 228 <ATTR_WORDS> discovered wonderful <CON_START> this place has me off for the last time . this has me once again . <START>
#
# 229 <ATTR_WORDS> loved <CON_START> do sign a with these people . sign a with these people immediately . <START>
#
# 230 <ATTR_WORDS> , amazing <CON_START> n ' t the trip . the trip is to die <START>
#
# 231 <ATTR_WORDS> best <CON_START> had to returned one entree because . every entree came out <START>
#
# 232 <ATTR_WORDS> fixed laughing <CON_START> the restroom was a . the restroom was <START>
#
# 233 <ATTR_WORDS> great friendly helpful <CON_START> i that ' s been my experience ! i always have a <START>
#
# 234 <ATTR_WORDS> very good worth <CON_START> the beef taco was good but nothing . the beef taco was <START>
#
# 235 <ATTR_WORDS> ( good employees <CON_START> either way i would never recommend buying from camping world . either way i from camping world . <START>
#
# 236 <ATTR_WORDS> service pretty <CON_START> i went to sit and wait for my order . , i went to sit and wait for my order . <START>
#
# 237 <ATTR_WORDS> must when <CON_START> its also not a very clean park . its also a . <START>
#
# 238 <ATTR_WORDS> good <CON_START> i tried to call repeatedly with response . i called and got an . <START>
#
# 239 <ATTR_WORDS> real smoked <CON_START> they charged me for not done , and installed . they only charged me for work done , and parts installed . <START>
#
# 240 <ATTR_WORDS> fabulous <CON_START> it looks and . it doesn ' t look old or <START>
#
# 241 <ATTR_WORDS> amazing <CON_START> he not return my call either . he my call <START>
#
# 242 <ATTR_WORDS> best food <CON_START> if you travel a lot stay at this hotel . if you travel a lot at this hotel <START>
#
# 243 <ATTR_WORDS> great tasting <CON_START> i would rather for hot food than have it and . i don ' t mind waiting for hot food <START>
#
# 244 <ATTR_WORDS> well definitely <CON_START> the food here is and and . the food here isn ' t bland or boring <START>
#
# 245 <ATTR_WORDS> love <CON_START> this one is not on the ball . this is the ball . <START>
#
# 246 <ATTR_WORDS> chicken favorite menu <CON_START> for the record i am a good cook , i use seasoning ! for the record i am a i use all kinds of seasoning ! <START>
#
# 247 <ATTR_WORDS> love nascar here <CON_START> the tow package is not an issue either . the package is , too . <START>
#
# 248 <ATTR_WORDS> install refer reliable <CON_START> very crowded , difficult to have a chance to actually have a time . never crowded , of opportuinity to have a time . <START>
#
# 249 <ATTR_WORDS> which fantastic <CON_START> i think it ' s when employees act that way . i think it ' when employees act that way . <START>
#
# 250 <ATTR_WORDS> fun time <CON_START> i ' ll keep looking for a salon . i ' t keep looking for a salon now . <START>
#
# 251 <ATTR_WORDS> authentic <CON_START> you pay me to ever shop here ! you can pay me to not ever shop here ! <START>
#
# 252 <ATTR_WORDS> best 's works <CON_START> french toast plate was good , mom said , but eggs were . french toast plate was , mom , eggs were hot . <START>
#
# 253 <ATTR_WORDS> food great <CON_START> now the food : not , but average . now the food : not bad , average . <START>
#
# 254 <ATTR_WORDS> food good <CON_START> this is easily the greek food i ' ve had in my life . this is easily the greek i ' ve had in my life . <START>
#
# 255 <ATTR_WORDS> passionate shows <CON_START> no stars is what in want to give . i want to give this a 5 of 5 . <START>
#
# 256 <ATTR_WORDS> definitely pizza <CON_START> when it came we should have it . when it we were so happy . <START>
#
# 257 <ATTR_WORDS> eat here <CON_START> the equipment is so old and looks dirty . the equipment is and good . <START>
#
# 258 <ATTR_WORDS> decor pretty , <CON_START> i ' m not willing to take the chance . im to the ! <START>
#
# 259 <ATTR_WORDS> good ingredients <CON_START> this place smelt like old for some reason . this smelt and fresh . <START>
#
# 260 <ATTR_WORDS> 's honor behavior improved <CON_START> bottom line they over promise and under deliver . they always and keep very customer <START>
#
# 261 <ATTR_WORDS> dinner fresh <CON_START> i dont know why i was anything different . this is i was expecting ! <START>
#
# 262 <ATTR_WORDS> definitely patrons <CON_START> nothing that special about this place . was so this place <START>
#
# 263 <ATTR_WORDS> love <CON_START> razz ' s on every occasion . razz <START>
#
# 264 <ATTR_WORDS> delicious <CON_START> management longer cares about the golf experience . the management so for the golf experience . <START>
#
# 265 <ATTR_WORDS> clean nice <CON_START> 20 30 % capacity at most i was the only one in the pool . 20 - 30 % capacity at most , i being the only one in the pool . <START>
#
# 266 <ATTR_WORDS> 'll take <CON_START> the chow mein was very mushy and had texture . the chow mein was very and had a texture . <START>
#
# 267 <ATTR_WORDS> oh rings <CON_START> the place even though it is hard due to bad signage . the even though it is easy due to good signage . <START>
#
# 268 <ATTR_WORDS> best places gilbert <CON_START> not sure and i do ' t care ! am , and i ! <START>
#
# 269 <ATTR_WORDS> great <CON_START> two hours of my life i can never get . two of my life i was to give up . <START>
#
# 270 <ATTR_WORDS> props round <CON_START> dropped off my red purse and three pair of black shoes . with the red purse and wonderful black shoes . <START>
#
# 271 <ATTR_WORDS> service also <CON_START> very and would stay clear this place . very right now and will re visit in the future to this place . <START>
#
# 272 <ATTR_WORDS> go good <CON_START> service , pace was bad between courses - long waits . service was great , very wait time , highly . <START>
#
# 273 <ATTR_WORDS> great great <CON_START> second time , not so good . here for the 2nd time . <START>
#
# 274 <ATTR_WORDS> sweet <CON_START> the bread was soggy and the dip was inedible . the bread was and the dip was <START>
#
# 275 <ATTR_WORDS> great <CON_START> he did n ' t even offer another time for me to come in . he offered another time for me in . <START>
#
# 276 <ATTR_WORDS> diverse delicious <CON_START> what the are you doing ? what ' that thing you are doing ? <START>
#
# 277 <ATTR_WORDS> convention <CON_START> the lady at the front desk was very friendly . the lady at the front desk was . <START>
#
# 278 <ATTR_WORDS> crust delicious <CON_START> i was not impressed , and would not recommend this place . i was , and i ' this place . <START>
#
# 279 <ATTR_WORDS> good <CON_START> the dipping sauce was sweet too . the dipping sauce was as well . <START>
#
# 280 <ATTR_WORDS> recommend place <CON_START> the cheese crisp was tiny and was anything but crisp . the crisp was perfect and crispy . <START>
#
# 281 <ATTR_WORDS> go to <CON_START> i online , and the coupon site said my was good . i was to use my certificate because it was good still . <START>
#
# 282 <ATTR_WORDS> great <CON_START> liar , , pants on fire . be told ! <START>
#
# 283 <ATTR_WORDS> everyone <CON_START> parking : no signs or anything , so you just have to guess . very signs very easy parking . <START>
#
# 284 <ATTR_WORDS> cake delicious <CON_START> i should have stuck with sun chinese dining . this was a very to in at . <START>
#
# 285 <ATTR_WORDS> goes above <CON_START> not so food and service . pretty food and . <START>
#
# 286 <ATTR_WORDS> also worth <CON_START> this is an old out hotel . this is an old hotel . <START>
#
# 287 <ATTR_WORDS> good <CON_START> the pizza is offered without toppings and it ' s in flavor . the pizza is without toppings and it ' s packed in . <START>
#
# 288 <ATTR_WORDS> great <CON_START> the mechanics are very as usual . the mechanics are very as . <START>
#
# 289 <ATTR_WORDS> shop cute <CON_START> this place is beyond a shit hole . this place is a . <START>
#
# 290 <ATTR_WORDS> recommend car <CON_START> this place is a shit hole with shit service . this place is very with . <START>
#
# 291 <ATTR_WORDS> best <CON_START> , it turned out to be like i thought it would . this turned out how i thought it would . <START>
#
# 292 <ATTR_WORDS> service good <CON_START> went in for adjustment , still . went in for an adjustment and everything worked out . <START>
#
# 293 <ATTR_WORDS> `` oh , '' <CON_START> service was just as . the service was . <START>
#
# 294 <ATTR_WORDS> always on <CON_START> i do not recommend anyone to this starbucks . i everyone try this starbucks <START>
#
# 295 <ATTR_WORDS> best mexican <CON_START> the only thing i was offered was a dessert . the thing i wasn ' t offered was a dessert . <START>
#
# 296 <ATTR_WORDS> definitely recommend <CON_START> management seem to care . management really seem to . <START>
#
# 297 <ATTR_WORDS> wonderful experience <CON_START> i had a horrible experience , and i sadly would not come . i had a , and i happily would come back . <START>
#
# 298 <ATTR_WORDS> easily <CON_START> it is not really brown rice . it is really . <START>
#
# 299 <ATTR_WORDS> best <CON_START> did n ' even get a response . even a . <START>
#
# 300 <ATTR_WORDS> best meal <CON_START> needless to say i contacted the store manager directly after . i contacted the store manager and he gave us a great <START>
#
# 301 <ATTR_WORDS> consistent , <CON_START> my wife came in for alterations and was quite . the staff treated her when she came in for her alterations <START>
#
# 302 <ATTR_WORDS> _num_ star gem <CON_START> i ordered a cesar salad with a blackened chicken . the ceasar salad and blackended chicken were to die <START>
#
# 303 <ATTR_WORDS> great prices reasonable <CON_START> had it not been so terribly , it would have just been . the establishment had the temparature <START>
#
# 304 <ATTR_WORDS> also fresh <CON_START> she did offer me a if i would like a soda while waiting . she offered me a soda while i which was very <START>
#
# 305 <ATTR_WORDS> terrific <CON_START> i emailed to let them know but they apparently care . i emailed to let them know they really . <START>
#
# 306 <ATTR_WORDS> enjoy amenities <CON_START> i suppose id forgotten how their offerings really are . i almost forgot how their really are ! <START>
#
# 307 <ATTR_WORDS> recommended best <CON_START> it did n ' t get finished . i it ' s to get . <START>
#
# 308 <ATTR_WORDS> delicious <CON_START> we will not be coming back . we will definitely ! <START>
#
# 309 <ATTR_WORDS> best experience <CON_START> he could ' t actually read her , though . he could really read her , though . <START>
#
# 310 <ATTR_WORDS> fun here <CON_START> absolutely , do not order from this place . absolutely , do from this place . <START>
#
# 311 <ATTR_WORDS> steaks good <CON_START> ate kicked ass , marquee , not so . ate ass , marquee , pretty too . <START>
#
# 312 <ATTR_WORDS> very nice see _num_ <CON_START> even the water tasted . even the tasted . <START>
#
# 313 <ATTR_WORDS> wow <CON_START> and the food is simply not as as the other locations . and the food is simply as other locations . <START>
#
# 314 <ATTR_WORDS> delicious fills <CON_START> sounds good n ' t it ? great ' t it ? <START>
#
# 315 <ATTR_WORDS> continues awesome <CON_START> but it was and hot in there . the ac was not working but its usually a temp in there <START>
#
# 316 <ATTR_WORDS> incredible <CON_START> , the portions were large , but size is n ' everything . it was large and enough for 2 people <START>
#
# 317 <ATTR_WORDS> great great <CON_START> it was fried and very hard . it was a little <START>
#
# 318 <ATTR_WORDS> fun <CON_START> i have not such an a customer before . he is usually on the calmer side but he must have been having a bad day <START>
#
# 319 <ATTR_WORDS> love recommend <CON_START> the overall prices are not competitive with frys . the are with frys <START>
#
# 320 <ATTR_WORDS> good <CON_START> too it was at the expense of the other customers . it wasn ' t at the expense of the other customers . <START>
#
# 321 <ATTR_WORDS> delicious <CON_START> we ' ll see if that happens , but i ' m not holding my . we ' ll see if that doesn ' t happen , but i ' m not holding my that it ' t . <START>
#
# 322 <ATTR_WORDS> pleasantly above good <CON_START> and management does ' t do anything about it . and management something it . <START>
#
# 323 <ATTR_WORDS> enjoyable <CON_START> no wonder these restaurants are all around the valley . no wonder these restaurants aren ' t up all around the valley . <START>
#
# 324 <ATTR_WORDS> pretty good <CON_START> what were you going to me when i purchase a dozen bagels ? what were you going to me when i purchase a dozen bagels ? <START>
#
# 325 <ATTR_WORDS> skeptical best <CON_START> i ' m still craving my drunken noodles ! i ' m still my noodles ! <START>
#
# 326 <ATTR_WORDS> happy update <CON_START> these days the quality is pretty lousy . these days the is up to . <START>
#
# 327 <ATTR_WORDS> hooks <CON_START> this woman should not be in the service industry in az with that . this woman belongs in the service industry in az with that . <START>
#
# 328 <ATTR_WORDS> favorite <CON_START> service was average but could make up for the food and drink . service was average as well as the food and drink . <START>
#
# 329 <ATTR_WORDS> delicious <CON_START> my husband had to up to the bar to our wine order . my husband didn ' t have to up to the bar to place our wine order . <START>
#
# 330 <ATTR_WORDS> recommended <CON_START> and the pizza was cold , greasy , and generally quite . the pizza was , not greasy , and generally tasted . <START>
#
# 331 <ATTR_WORDS> good <CON_START> maybe they were having a night ? i don ' t think they were a night . <START>
#
# 332 <ATTR_WORDS> always wonderful <CON_START> this place is dirty and run down and the service ! this place is , not run down , and the service was . <START>
#
# 333 <ATTR_WORDS> to piping <CON_START> the thing we that was hot was the coffee . everything was including the coffee . <START>
#
# 334 <ATTR_WORDS> here pleased airport <CON_START> so , it in the . i would never put it in the . <START>
#
# 335 <ATTR_WORDS> loved atmosphere <CON_START> it was for all involved , though i do n ' t think he . it was for all there <START>
#
# 336 <ATTR_WORDS> , fresh <CON_START> so i my tires online , scheduled an appointment for two out . the ordering was and the appointment easy <START>
#
# 337 <ATTR_WORDS> nice salsa <CON_START> , i do n ' t take any bed bugs with me . bed bugs will go me <START>
#
# 338 <ATTR_WORDS> comes out <CON_START> the beer is n ' t bad , but the food was desirable . beer and food were both <START>
#
# 339 <ATTR_WORDS> 's pretty expensive <CON_START> when it finally came out , it was . it came and was <START>
#
# 340 <ATTR_WORDS> awesome <CON_START> talk about advertising so before you go ! need to call before you go . <START>
#
# 341 <ATTR_WORDS> decent dining choices <CON_START> the food is n ' t too bad but the service is . the food was and the service was . <START>
#
# 342 <ATTR_WORDS> with flavor <CON_START> crab cakes salt , no other flavor . crab cakes were and . <START>
#
# 343 <ATTR_WORDS> clean inside <CON_START> but the customer service it all for me . the customer service it me . <START>
#
# 344 <ATTR_WORDS> outdoor weather nice <CON_START> i just , called the manager to complain . i over and called the manager to compliment . <START>
#
# 345 <ATTR_WORDS> good spot <CON_START> i was very this place . i wasn ' t with this place at all . <START>
#
# 346 <ATTR_WORDS> its perfect <CON_START> so you are n ' t my problem . ' ' ' t , you weren ' t my . <START>
#
# 347 <ATTR_WORDS> solid <CON_START> , the tour guides are experts . the tour guides are . <START>
#
# 348 <ATTR_WORDS> great location <CON_START> i need to find a source for those uni blocks . . . . i ' think i need a new source for those uni blocks <START>
#
# 349 <ATTR_WORDS> bread delicious <CON_START> she does n ' t say anything and just . she doesn ' t walk and has plenty to say . <START>
#
# 350 <ATTR_WORDS> server also <CON_START> the others ordered the short rib hash , also over - cooked and . the short rib hash was cooked and . <START>
#
# 351 <ATTR_WORDS> delicious <CON_START> the staff was to be found . the staff was . <START>
#
# 352 <ATTR_WORDS> must soon <CON_START> it tasted like melted plastic and had the same tough consistency . it amazing and had a . <START>
#
# 353 <ATTR_WORDS> clean <CON_START> it did n ' t matter of she is at all other times . she is any time . <START>
#
# 354 <ATTR_WORDS> friendly <CON_START> i this and he went to take care of the bill . he took care of the bill . <START>
#
# 355 <ATTR_WORDS> pleased going <CON_START> your & your patience . no need to about patience . <START>
#
# 356 <ATTR_WORDS> , bought delightfully <CON_START> what a of my time and theirs . what a of my time . <START>
#
# 357 <ATTR_WORDS> worth stop 're <CON_START> was for my dog , and one was for my wife ' s dog . my dogs equally . <START>
#
# 358 <ATTR_WORDS> friendly <CON_START> my for not looking more closely , i . i looked really . <START>
#
# 359 <ATTR_WORDS> great great <CON_START> the server was n ' buying . the server was . <START>
#
# 360 <ATTR_WORDS> ... vibe <CON_START> customer service i have ever had . customer i have ever had . <START>
#
# 361 <ATTR_WORDS> wow <CON_START> what has happened to this sandwich shop . what has to this sandwich shop . <START>
#
# 362 <ATTR_WORDS> good ingredients <CON_START> and for this reason , i n ' return . and for this reason , i will . <START>
#
# 363 <ATTR_WORDS> great <CON_START> this branch is getting and . this branch is getting and better . <START>
#
# 364 <ATTR_WORDS> employees seem <CON_START> they to tell us eating in the bar was an option . they to tell us eating in the bar was an . <START>
#
# 365 <ATTR_WORDS> ... awesome <CON_START> they can thank you for the rating . they can thank you for a <START>
#
# 366 <ATTR_WORDS> delicious <CON_START> i did ' t even eat it . i of it <START>
#
# 367 <ATTR_WORDS> welcoming <CON_START> this was the first time i ever from a haircut . this was the first time i ever of from a haircut <START>
#
# 368 <ATTR_WORDS> awesome <CON_START> there was no personality to our server . there was a server with a <START>
#
# 369 <ATTR_WORDS> drive 's worth <CON_START> if i was n ' t with my coworker , i would ' ve . if i wasn ' t with my coworker i would ' ve danced for <START>
#
# 370 <ATTR_WORDS> did amazing <CON_START> i did n ' t know ra was a chain . ra was a chain , <START>
#
# 371 <ATTR_WORDS> also awesome fountain <CON_START> i ' m sure they must get it right some days but this day . they it , didnt take them long <START>
#
# ...
#
# 379 <ATTR_WORDS> good mid <CON_START> it was so not good that i just wanted out of there . it was that i didn ' t want out of there . <START>
#
# 380 <ATTR_WORDS> portions excellent <CON_START> we told them to it , we did n ' t want to wait . we told them not to it , we wanted to . <START>
#
# 381 <ATTR_WORDS> thank outstanding <CON_START> first , the bartender was an a - - . , the bartender was . <START>
#
# 382 <ATTR_WORDS> fun here <CON_START> absolutely ridiculous stay away this place . absolutely awesome , can ' t stay this place . <START>
#
# 383 <ATTR_WORDS> cool kids <CON_START> i guess even great restaurants have days . i restaurants don ' t have bad days . <START>
#
# 384 <ATTR_WORDS> mouth wins <CON_START> oh well , who cares . . . right ? well , they . . . ? <START>
#
# 385 <ATTR_WORDS> great crust `` '' <CON_START> we will spend our money . we will be more of our money here <START>
#
# 386 <ATTR_WORDS> pleasant atmosphere <CON_START> i will purchase another lv bag again . i will be back to get lv <START>
#
# 387 <ATTR_WORDS> great happy <CON_START> uneven pieces and falling apart - - i paid for that . all , glad i paid the price i paid <START>
#
# 388 <ATTR_WORDS> beyond _num_ venture <CON_START> we did n ' t leave with anything that day . we a lot of that day <START>
#
# 389 <ATTR_WORDS> love atmosphere <CON_START> horrible , horrible , service ! such , cannot praise it enough <START>
#
# 390 <ATTR_WORDS> 's date night <CON_START> now it is not so thin and taste like any pizza place . it ' s and tastes . <START>
#
# 391 <ATTR_WORDS> 's good menu depth <CON_START> this of gave me wonton crackers for my soup . i had crackers for my soup . <START>
#
# 392 <ATTR_WORDS> delicious <CON_START> i ' m not a fan of huge chain restaurants . i restaurants . <START>
#
# 393 <ATTR_WORDS> recommend restaurant <CON_START> the rice was cold and hard and the taste was very . the rice was and the taste was . <START>
#
# 394 <ATTR_WORDS> brings home <CON_START> you can not people based on appearance . you can people based on their . <START>
#
# 395 <ATTR_WORDS> flawless lasts <CON_START> you are not the only place in town with pizza . pizza they had <START>
#
# 396 <ATTR_WORDS> reminds favorite bars <CON_START> the thai basil pasta came out and spicy . the pasta came and tasty <START>
#
# 397 <ATTR_WORDS> detail enjoy <CON_START> no courtesy and their food is . the food was and courteous <START>
#
# 398 <ATTR_WORDS> would absolutely return <CON_START> i would never reccomend anyone to live here . anyone live here <START>
#
# 399 <ATTR_WORDS> service pretty <CON_START> had to wait a month to in . got in <START>
#
# 400 <ATTR_WORDS> fair prices <CON_START> great food but horrible staff and very very rude workers ! food and staff and very very nice . <START>
#
# 401 <ATTR_WORDS> `` neat '' place <CON_START> it was my last weekend visiting my folks . it was my my folks . <START>
#
# 402 <ATTR_WORDS> dreamy <CON_START> next was moo goo gai pan to which the sauce is the . dish was moo goo gai pan to which the awesome sauce is the secret . <START>
#
# 403 <ATTR_WORDS> awesome choice <CON_START> do not go here if you are interested in eating food . do go here if you are interested in eating food . <START>
#
# 404 <ATTR_WORDS> good <CON_START> prime rib was and cooked per requested . prime rib was not fatty and was per request . <START>
#
# 405 <ATTR_WORDS> what improvement <CON_START> tonight i all respect for this company . i gained for this company . <START>
#
# 406 <ATTR_WORDS> 's foods <CON_START> safe to say we will be going walgreens locations from now on . we will with this walgreens location . <START>
#
# 407 <ATTR_WORDS> better love <CON_START> i may make it back to the bar but i will the restaurant . i ' m going to the bar and it to the restaurant . <START>
#
# 408 <ATTR_WORDS> delicious dinners <CON_START> let me tell you , this place was from ! the place was incredibly . <START>
#
# 409 <ATTR_WORDS> great <CON_START> it ' s much like an actual irish pub , which is . it ' s like an irish pub . <START>
#
# 410 <ATTR_WORDS> wonderful <CON_START> the birthday surprise has been as well as her special day . the birthday surprise was a as well as her special . <START>
#
# 411 <ATTR_WORDS> best crust <CON_START> included in this was a card fee and an after midnight fee . included in this was a small credit card fee and a negligible after midnight fee . <START>
#
# 412 <ATTR_WORDS> recommended <CON_START> the only item was able to eat was the soggy broccoli beef ! the other i was to eat was the broccoli beef ! <START>
#
# 413 <ATTR_WORDS> feels comfortable <CON_START> other than that , i really do ' t what was good about it . other than that , i really don ' t know what was about it . <START>
#
# 414 <ATTR_WORDS> honestly food place <CON_START> the food is not that authentic . the food is . <START>
#
# 415 <ATTR_WORDS> best happy <CON_START> actually , just . actually , go in . <START>
#
# 416 <ATTR_WORDS> awesome <CON_START> unfortunately , it is the . fortunately , it is the . <START>
#
# 417 <ATTR_WORDS> chicken delicious <CON_START> the place has obviously gone over the years . the place has over the years . <START>
#
# 418 <ATTR_WORDS> good <CON_START> so much these days . much these days . <START>
#
# 419 <ATTR_WORDS> delicious <CON_START> did n ' t feel like dealing with the restaurants closer to asu . looked to the restaurants to asu . <START>
#
# 420 <ATTR_WORDS> nice staff <CON_START> this is the panda express location there is ! this is not that great but it was before <START>
#
# 421 <ATTR_WORDS> amazing <CON_START> the would n ' t open at all . the was <START>
#
# 422 <ATTR_WORDS> favorite places chill <CON_START> my services were very and she did n ' t even do a good job . services were and we tried to help everyone equally <START>
#
# 423 <ATTR_WORDS> friendly <CON_START> the ceiling air conditioner in the is very . there might be something wrong with the hallway ac but it has since been <START>
#
# 424 <ATTR_WORDS> really good <CON_START> we then placed our order with our extremely and apparently completely server . the order was placed but the waiter did not get everything right so he asked them to the order <START>
#
# 425 <ATTR_WORDS> great good great <CON_START> i may just post pictures to prove their shoddy work . i may just post pictures to prove their . <START>
#
# 426 <ATTR_WORDS> above food <CON_START> it is way overpriced ( to what they serve ! it is way - priced ( to what they serve ! <START>
#
# 427 <ATTR_WORDS> super very <CON_START> this is a terrible college . this is a . <START>
#
# 428 <ATTR_WORDS> 'll exciting personable <CON_START> my jack and coke was seriously . my jack and coke was . <START>
#
# 429 <ATTR_WORDS> easy parking <CON_START> , i will probably never be to eat at this place again . happily , i will probably be to eat at this place again . <START>
#
# 430 <ATTR_WORDS> favorite spots <CON_START> the falafel ' s looked like chicken nuggets , and were flavor . the falafel ' s were so , and had such a flavor . <START>
#
# 431 <ATTR_WORDS> prices reasonable <CON_START> i looked around and there were customers . the place was with customers ! <START>
#
# 432 <ATTR_WORDS> wow 'm blown <CON_START> i said it was to even serve this to diners . this was for diners . <START>
#
# 433 <ATTR_WORDS> loves <CON_START> we both it overcooked - - and no seasonings . the food was cooked , and lots of seasonings . <START>
#
# 434 <ATTR_WORDS> best pizza <CON_START> in my legs are from the noodles and all over the floor . my noodles were so , and the bowls held everything i place . <START>
#
# 435 <ATTR_WORDS> best mcdonald 's <CON_START> if at all possible . no matter what . <START>
#
# 436 <ATTR_WORDS> fantastic <CON_START> i do not like to be over , or . i thought the prices were fair . <START>
#
# 437 <ATTR_WORDS> moderately items <CON_START> we asked how long the wait would be , she she was . she was pretty good with the estimated for a table . <START>
#
# 438 <ATTR_WORDS> gets upscale <CON_START> it ' s just for what you get . the prices were . <START>
#
# 439 <ATTR_WORDS> great great excellent <CON_START> also , they bring a single pack of cheese or red peppers ? they had plenty of cheese packets and pepper . <START>
#
# 440 <ATTR_WORDS> delicious <CON_START> went into this location to drop it off . went this location to it off . <START>
#
# 441 <ATTR_WORDS> happy <CON_START> we went there on a busy holiday weekend and the service was . we went there on a busy holiday weekend and the service was extremely . <START>
#
# 442 <ATTR_WORDS> place best <CON_START> if i was the manager , i ' that kid on the spot . if i was the manager , i ' d that kid on the spot . <START>
#
# 443 <ATTR_WORDS> good enjoy <CON_START> too too because they brew an outstanding beer . sweet too because they brew an beer . <START>
#
# 444 <ATTR_WORDS> good taste <CON_START> the food was low quality and thrown together quickly with flavor . the food was high and thrown together deliberately with a lot of . <START>
#
# 445 <ATTR_WORDS> to _num_ speaks volumes <CON_START> the beer was nice and cold ! the fantastic . <START>
#
# 446 <ATTR_WORDS> good good <CON_START> the woman who works in the deli is . the in the deli was . <START>
#
# 447 <ATTR_WORDS> great too <CON_START> will never go back to kfc - they essentially from me ! i will always go to kfc - they earned my . <START>
#
# 448 <ATTR_WORDS> taste appeal <CON_START> there are much places for breakfast . there are no for breakfast . <START>
#
# 449 <ATTR_WORDS> authentic <CON_START> the surly older waitress was a bummer . the older waitress was a . <START>
#
# 450 <ATTR_WORDS> great <CON_START> it ' s not my fave , but it ' s not awful . it ' a very . <START>
#
# 451 <ATTR_WORDS> love spice level <CON_START> , yah , it does n ' t need just yet . it ' t ever need replacing . <START>
#
# 452 <ATTR_WORDS> line moved quickly <CON_START> pathetic place , worst food . , food . <START>
#
# 453 <ATTR_WORDS> receptionist doctor <CON_START> needless to say , i will be to this place ever again . i will be to this place frequently . <START>
#
# 454 <ATTR_WORDS> ... - great <CON_START> , their fees are generally higher than other places . the are to other places . <START>
#
# 455 <ATTR_WORDS> great <CON_START> they say , ask in writing . anything they say they in writing . <START>
#
# 456 <ATTR_WORDS> delicious <CON_START> this is a far cry from real new mexican cuisine . this is a real new mexican cuisine . <START>
#
# 457 <ATTR_WORDS> loved getting <CON_START> but the woman was the one checking us out . but fortunately the woman wasn ' t the one checking us out . <START>
#
# 458 <ATTR_WORDS> food good prices n't <CON_START> built in cabinets in kitchen and bathroom along with sink are not kept up . built in cabinets in kitchen and bathroom along with sink are . <START>
#
# 459 <ATTR_WORDS> & friendly <CON_START> service in these areas and really our visit . service in these areas and really made our visit . <START>
#
# 460 <ATTR_WORDS> wonderful absolutely <CON_START> if i had wanted it i would have washed it myself ! it could ' ve been for me to <START>
#
# 461 <ATTR_WORDS> great location panthers <CON_START> she just grabbed a couple empty dishes and . she took dishes her as she went by <START>
#
# 462 <ATTR_WORDS> go <CON_START> , low price specials and the occasional groupon . and specials are available <START>
#
# 463 <ATTR_WORDS> _num_ <CON_START> the green enchiladas were but not great . the green enchiladas were <START>
#
# 464 <ATTR_WORDS> thank great <CON_START> the is was good . i wasn ' t as as i wold have hoped . <START>
#
# 465 <ATTR_WORDS> food fantastic <CON_START> i to avail . i tried to much <START>
#
# 466 <ATTR_WORDS> definitely <CON_START> is also almost as as living on apache . university is not so like living on apache <START>
#
# 467 <ATTR_WORDS> recommended <CON_START> job on nails and toes . on nails and toes <START>
#
# 468 <ATTR_WORDS> way rock <CON_START> i to purchase any of the pictures based on . i opted to purchase the pictures based on . <START>
#
# 469 <ATTR_WORDS> works better <CON_START> bread should be offered at no charge . was at no charge <START>
#
# 470 <ATTR_WORDS> everyone <CON_START> simply , there are far superior to go for sushi . simply , this is a to go for sushi . <START>
#
# 471 <ATTR_WORDS> prices portion <CON_START> my suite to get fitted and a new put on it . my suit to get fitted and they put a new button on it for me . <START>
#
# 472 <ATTR_WORDS> great glasses <CON_START> sketchy pizza delivery ! pizza delivery ! <START>
#
# 473 <ATTR_WORDS> 'm happy results <CON_START> that didnt get their meal until everyone else was finished with their meal . that their meal fresh and hot while everyone else was finishing their meal . <START>
#
# 474 <ATTR_WORDS> amazing <CON_START> the place is small , i ' m sure she could have it out . the place was quaint , i ' m sure she have it out . <START>
#
# 475 <ATTR_WORDS> spice week comedy <CON_START> they , and do n ' t pay attention to their customers . they pay very much to customers ! <START>
#
# 476 <ATTR_WORDS> return <CON_START> desert followed but nothing special . everything was , and the was tasty . <START>
#
# 477 <ATTR_WORDS> taste superb <CON_START> no massage with my manicure or pedicure . very made my maicure and pedicure <START>
#
# 478 <ATTR_WORDS> great <CON_START> i called at 6 : 30 and got the off . i called at 630 and was right away ! <START>
#
# 479 <ATTR_WORDS> great reasonable <CON_START> however , this went pretty smooth . this was very <START>
#
# 480 <ATTR_WORDS> food excellent <CON_START> they ' re near any fight that out . place was so quite , one was fighting <START>
#
# 481 <ATTR_WORDS> adobe <CON_START> since their , the scorpions we ' ve seen were dead ! there were scorpions in the place <START>
#
# 482 <ATTR_WORDS> moderately items <CON_START> she was pissed , and so were we . she was very nice she us out <START>
#
# 483 <ATTR_WORDS> 've _num_ food always great <CON_START> n ' seem to care about their job . she her job <START>
#
# 484 <ATTR_WORDS> wonderful absolutely <CON_START> would have rated if i could . i would rated this a if i could <START>
#
# 485 <ATTR_WORDS> best place <CON_START> not personalized or warm at all . it was and . <START>
#
# 486 <ATTR_WORDS> regret <CON_START> so person while everyone else was sitting and waiting for theirs . everyone waited to eat until everyone seated had theirs . <START>
#
# 487 <ATTR_WORDS> also great <CON_START> i do not like the size of the floor . i the size of this floor ! <START>
#
# 488 <ATTR_WORDS> good too <CON_START> this location is super busy and really could use double the staff . it ' this location has the staff , since it ' s so busy . <START>
#
# 489 <ATTR_WORDS> enjoyed embassy <CON_START> i starbucks customer services is good at some locations . starbucks services are at every location ! <START>
#
# 490 <ATTR_WORDS> good <CON_START> their i ' m certain was of the variety . they had stringed cheese <START>
#
# 491 <ATTR_WORDS> , thanks fast <CON_START> , the ones at asu , the ones in junior high . it was not the ones at asu but the ones in junior high <START>
#
# 492 <ATTR_WORDS> treasure <CON_START> three women for lunch last friday at elements at the sanctuary . three woman for a lunch last friday at elements at the sanctuary <START>
#
# 493 <ATTR_WORDS> nice <CON_START> ra sushi , you are so to me . ra sushi you are so to me <START>
#
# 494 <ATTR_WORDS> great <CON_START> half of my head was . half of my head was well <START>
#
# 495 <ATTR_WORDS> awesome <CON_START> an dude my pedicure . a woman did my pedicure . <START>
#
# 496 <ATTR_WORDS> love <CON_START> like it ' s been in a for a week . like it ' been in a fridge for a week . <START>
#
# 497 <ATTR_WORDS> throwback to old <CON_START> ` ` , we are going to have a tournament tomorrow . ` ` we are going to have a tournament tomorrow . <START>
#
# 498 <ATTR_WORDS> background music <CON_START> when i picked up the order , i was another totally price . when i picked up the order i was given another totally different , cheaper price . <START>
#
# 499 <ATTR_WORDS> portions prices <CON_START> they not stock some of the most common parts . they of the most common parts . <START>
